# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import itertools
from itertools import groupby
import os

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1,2"
# %matplotlib inline

# %% [markdown]
# # 1. Data Load
# ### 전처리 width, height, input_channel 정의

# %%
from load_data import load_data,class_breakdown

# %%
#data_name ="EEG"
#data_name ="HAR"

data_name ="UWaveGestureLibraryAll"
trainx, testx,trainy,testy,batch_size = load_data(data_name =data_name)
# Out:
# Load data UWaveGestureLibraryAll
# batch size:64
# train data (3582, 945),(3582,)
# test data (896, 945),(896,)

# %%
class_breakdown(trainy)
class_breakdown(testy)
# Out:
# Class=1, total=437, percentage=12.200
# Class=2, total=452, percentage=12.619
# Class=3, total=454, percentage=12.674
# Class=4, total=450, percentage=12.563
# Class=5, total=433, percentage=12.088
# Class=6, total=449, percentage=12.535
# Class=7, total=447, percentage=12.479
# Class=8, total=460, percentage=12.842
# Class=1, total=122, percentage=13.616
# Class=2, total=108, percentage=12.054
# Class=3, total=106, percentage=11.830
# Class=4, total=110, percentage=12.277
# Class=5, total=127, percentage=14.174
# Class=6, total=111, percentage=12.388
# Class=7, total=112, percentage=12.500
# Class=8, total=100, percentage=11.161

# %%
hot_encoded_y_train = np.asarray(pd.get_dummies(np.asarray(trainy.flatten())))
hot_encoded_y_test = np.asarray(pd.get_dummies(np.asarray(testy.flatten())))
print("y train shape: {}".format(hot_encoded_y_train.shape))
print("y test shape: {}".format(hot_encoded_y_test.shape))
# Out:
# y train shape: (3582, 8)
# y test shape: (896, 8)

# %% [markdown]
# ## 데이터 정규화

# %%
plt.plot(trainx[0])

# %%
from tslearn.preprocessing import TimeSeriesScalerMeanVariance, TimeSeriesResampler
trainx =TimeSeriesScalerMeanVariance().fit_transform(trainx)
testx =TimeSeriesScalerMeanVariance().fit_transform(testx)

# %%
plt.plot(trainx[0])

# %%
trainX = trainx[:, np.newaxis, :]
trainY = hot_encoded_y_train

validX =testx[:len(testx)//2,np.newaxis,:]
validY= hot_encoded_y_test[:len(testx)//2]

testX = testx[len(testx)//2:,np.newaxis,:]
testY = hot_encoded_y_test[len(testx)//2:]

print ("trainX shape:{}".format(trainX.shape))
print ("trainY shape:{}".format(trainY.shape))
print ("validX shape:{}".format(validX.shape))
print ("validY shape:{}".format(validY.shape))
print ("testX shape:{}".format(testX.shape))
print ("testY shape:{}".format(testY.shape))
# Out:
# trainX shape:(3582, 1, 945, 1)
# trainY shape:(3582, 8)
# validX shape:(448, 1, 945, 1)
# validY shape:(448, 8)
# testX shape:(448, 1, 945, 1)
# testY shape:(448, 8)

# %%
height = trainX.shape[1]
width = trainX.shape[2]
input_channel = trainX.shape[3]

print ("height {}".format(height))
print ("width {}".format(width))
print ("input_channel {}".format(input_channel))
# Out:
# height 1
# width 945
# input_channel 1

# %% [markdown]
# # 2. Training condition 정의

# %%
t_loss=[]
t_acc=[]

v_loss=[]
v_acc=[]

val_freq = 1
save_freq = 1
num_epochs= 300


std= 0.01
l_rate = 1e-5

# %%
train_history = pd.DataFrame(index=np.arange(0, num_epochs), columns=['epoch', 'loss', 'acc','timestamp'])
valid_history = pd.DataFrame(index=np.arange(0, num_epochs/val_freq),columns=['epoch', 'loss', 'acc','timestamp'])

# %% [markdown]
# # 3. model structure 정의

# %%
import tensorflow as tf
# Out:
# /home/gin908/paper_ready/py_36_env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/gin908/paper_ready/py_36_env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/gin908/paper_ready/py_36_env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/gin908/paper_ready/py_36_env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:522: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/gin908/paper_ready/py_36_env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/gin908/paper_ready/py_36_env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
class conv3_basic_CNN:
    def __init__(self, featuremap1, featuremap2, featuremap3,
                 conv1_size, conv2_size, conv3_size,
                 conv1_stride, conv2_stride, conv3_stride, 
                 conv1_channel, conv2_channel, conv3_channel,
                 pool1_size, pool2_size, pool3_size,
                 pool1_stride, pool2_stride, pool3_stride,
                 std=0.01, batch_size=64,width=500, height =1, input_channel=3, 
                 nb_classes=2, l_rate =1e-6,
                 reuse = False):
        self.std=std
        self.batch_size=batch_size
        self.height = height
        self.width = width
        self.input_channel = input_channel
        self.l_rate = l_rate
        
        self.feature1 = featuremap1
        self.feature2 = featuremap2
        self.feature3 = featuremap3
        
        self.conv1_size = conv1_size
        self.conv2_size = conv2_size
        self.conv3_size = conv3_size
        
        self.conv1_stride = conv1_stride
        self.conv2_stride = conv2_stride
        self.conv3_stride = conv3_stride
        
        self.conv1_channel = conv1_channel
        self.conv2_channel = conv2_channel
        self.conv3_channel = conv3_channel
        
        self.pool1_size = pool1_size
        self.pool2_size = pool2_size
        self.pool3_size = pool3_size
        
        self.pool1_stride = pool1_stride
        self.pool2_stride = pool2_stride
        self.pool3_stride = pool3_stride
        
        self.nb_classes = nb_classes

        with tf.name_scope('Classifier'):
            self.y_ = tf.placeholder(tf.float32, [None, self.nb_classes], name='truth')
            self.x =tf.placeholder(tf.float32, [None, 1,trainX.shape[2],trainX.shape[3]],name='x')
            self.keep_prob = tf.placeholder(tf.float32,name="keep_probability")

        # keep prob가 1보다 작으면, 드랍아웃을 한다는 의미
        #self.dropout_bool = True#tf.cond(self.keep_prob < 1.0, lambda: tf.constant(True), lambda: tf.constant(False))
        
        self.logits = self.build_model()

        # Define loss and optimizer, minimize the squared error
        self.cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(logits = self.y, labels= self.y_)
        self.cost = tf.reduce_mean(self.cross_entropy)
        self.optimizer = tf.train.AdamOptimizer(learning_rate=self.l_rate).minimize(self.cost)

        self.correct_pred = tf.equal(tf.argmax(self.y, 1), tf.argmax(self.y_, 1))
        self.accuracy = tf.reduce_mean(tf.cast(self.correct_pred, tf.float32))

        init = tf.global_variables_initializer()

        # Launch the session
        self.session_conf = tf.ConfigProto()
        self.session_conf.gpu_options.allow_growth = True
        self.sess = tf.InteractiveSession(config=self.session_conf)
        self.sess.run(init)

        self.saver = tf.train.Saver(max_to_keep=None)

    def build_model(self):
        xavier = tf.contrib.layers.xavier_initializer_conv2d()  
        self.conv1_weights = tf.get_variable(name="c1", initializer=xavier, shape=[1, self.conv1_size, trainX.shape[-1], conv1_channel])
        self.conv1_biases = tf.Variable(tf.zeros([conv1_channel]))
        self.conv2_weights = tf.get_variable(name="c2", initializer=xavier, shape=[1, self.conv2_size, self.conv1_channel, conv2_channel])
        self.conv2_biases = tf.Variable(tf.zeros([conv2_channel]))
        self.conv3_weights = tf.get_variable(name="c3", initializer=xavier, shape=[1, self.conv3_size, self.conv2_channel, conv3_channel])
        self.conv3_biases = tf.Variable(tf.zeros([conv3_channel]))
        self.fc1_weights = tf.Variable(tf.truncated_normal([1 * self.feature3  * self.conv3_channel, self.nb_classes], stddev=0.1))
        self.fc1_biases = tf.Variable(tf.zeros([self.nb_classes]))

        with tf.variable_scope('layer0'):
            #b, h, w, c
            self.reshaped_input = tf.reshape(self.x, [-1, 1, trainX.shape[2],trainX.shape[3]], name="absolute_input")
        # Convolutional Layer #1 and Pooling Layer #1
        with tf.variable_scope('layer1'):
            self.conv1 = tf.nn.conv2d(self.reshaped_input, self.conv1_weights, strides=[1, 1, self.conv1_stride, 1], padding='SAME')
            self.relu1 = tf.nn.relu(tf.nn.bias_add(self.conv1, self.conv1_biases))
            self.pool1 =  tf.nn.max_pool(self.relu1, ksize=[1, 1, self.pool1_size, 1], strides=[1, 1, self.pool1_stride, 1],  padding='VALID')
            self.dropout1 = tf.nn.dropout(self.pool1, self.keep_prob)

        # Convolutional Layer #1 and Pooling Layer #2
        with tf.variable_scope('layer2'):
            self.conv2 = tf.nn.conv2d(self.dropout1, self.conv2_weights, strides=[1, 1, self.conv2_stride, 1], padding='SAME')
            self.relu2 = tf.nn.relu(tf.nn.bias_add(self.conv2, self.conv2_biases))
            self.pool2 =  tf.nn.max_pool(self.relu2, ksize=[1, 1, self.pool2_size, 1], strides=[1, 1, self.pool2_stride, 1],  padding='VALID')
            self.dropout2 = tf.nn.dropout(self.pool2, self.keep_prob)

        #Convolutional Layer #1 and Pooling Layer #3
        with tf.variable_scope('layer3'):
            self.conv3 = tf.nn.conv2d(self.dropout2, self.conv3_weights, strides=[1, 1, self.conv3_stride, 1], padding='SAME')
            self.relu3 = tf.nn.relu(tf.nn.bias_add(self.conv3, self.conv3_biases))
            self.pool3 =  tf.nn.max_pool(self.relu3, ksize=[1, 1, self.pool3_size, 1], strides=[1, 1, self.pool3_stride, 1],  padding='VALID')
            self.dropout3 = tf.nn.dropout(self.pool3, self.keep_prob)

        # Dense Layer with Relu
        with tf.variable_scope('layer4'):
            self.pool_shape = self.dropout3.get_shape().as_list()
            self.reshaped = tf.reshape(self.dropout3, [-1, self.pool_shape[1] * self.pool_shape[2] * self.pool_shape[3]])
            self.y = tf.add(tf.matmul(self.reshaped, self.fc1_weights), self.fc1_biases, name="absolute_output")
            self.prediction = tf.nn.softmax(self.y)
            
        return self.y


    def train(self, data, target, keep_prob):
        opt, cost ,acc = self.sess.run((self.optimizer,self.cost, self.accuracy ), 
                             feed_dict={self.y_: target,
                                        self.x: data,
                                       self.keep_prob: keep_prob})
        return cost,acc

    def test(self, data, target, keep_prob):
        cost,acc = self.sess.run((self.cost,self.accuracy),
                             feed_dict={self.y_: target,
                                        self.x: data,
                                        self.keep_prob : keep_prob})
        return cost,acc

    def get_output(self, output,data, keep_prob):
        output =  self.sess.run((output), feed_dict={self.x: data,self.keep_prob: keep_prob})
        return output
    
    def predict(self, data, keep_prob):

        prediction =  self.sess.run((self.prediction), feed_dict={self.x: data,self.keep_prob: keep_prob})
        return prediction

    def save(self, save_path='./model.ckpt'):
        saved_path = self.saver.save(self.sess, save_path)
        print("Model saved in file: %s"%saved_path)

    def load(self, load_path = './model.ckpt'):
        self.saver.restore(self.sess, load_path)
        print("Model restored")

    def terminate(self):
        self.sess.close()
        tf.reset_default_graph()

# %%
from numpy import unique
nb_classes =trainY.shape[1]
print (nb_classes)
# Out:
# 8

# %% [markdown]
# <font color='red'> turn off 구조는 마지막 convolution layer activation output 에 weight를 elementwise multiply 구조.
# train, test시에는 이 weight를 모두 1로 고정하며,
# prdiction 시에는 convolution layer activation output에서 상위 T%를 turn off 시키며 accuracy의 변화가 A 이상인 경우를
# threshold로 정하기 위해 이러한 모델 구조가 설정되었습니다.</font>
#
# <font color='blue'> CNN_MC_dropout_last_conv_turnoff</font> 모델은 상위 T%의 output을 가지는 last convolution output을 0으로 turn off 시키는 구조입니다.
#
# 반면, <font color='blue'> CNN_MC_dropout_input_turnoff</font> 모델은 상위 T%의 output을 가지는 last convolution output에 매칭되는(하이라이트 되는 인풋)을 0으로 turn off 시키는 구조입니다.

# %%
import math
if data_name in ["HAR","EEG"]:
    conv1_channel = 32
    conv2_channel = 64
    conv3_channel = 128

    ###### conv1
    conv1_size = 7
    conv1_pad = int((conv1_size -1) /2)
    conv1_stride = 2

    pool1_size = 4
    pool1_pad = 0
    pool1_stride = 2

    ###### conv2
    conv2_size = 5
    conv2_pad = int((conv2_size -1) /2)
    conv2_stride = 1

    pool2_size = 4
    pool2_pad = 0
    pool2_stride = 2

    ###### conv3
    conv3_size = 3
    conv3_pad = int((conv3_size -1) /2)
    conv3_stride = 1

    pool3_size = 2
    pool3_pad = 0
    pool3_stride = 1
elif data_name in "UWaveGestureLibraryAll":
    conv1_channel = 32
    conv2_channel = 64
    conv3_channel = 128

    ###### conv1
    conv1_size = 15
    conv1_pad = int((conv1_size -1) /2)
    conv1_stride = 2

    pool1_size = 8
    pool1_pad = 0
    pool1_stride = 4

    ###### conv2
    conv2_size = 11
    conv2_pad = int((conv2_size -1) /2)
    conv2_stride = 1

    pool2_size = 4
    pool2_pad = 0
    pool2_stride = 2

    ###### conv3
    conv3_size = 7
    conv3_pad = int((conv3_size -1) /2)
    conv3_stride = 1

    pool3_size = 4
    pool3_pad = 0
    pool3_stride = 2

# %%
conv1_idx_list=[]
for conv1_idx in range(0,trainX.shape[2],conv1_stride):
    conv1_idx_list.append(np.arange(max(conv1_idx-(conv1_size//2),0), min(conv1_idx+(conv1_size//2) +1 ,trainX.shape[2])))

if conv1_idx < (trainX.shape[2]-1):
    for data_idx in np.arange(conv1_idx+1, trainX.shape[2]):
        conv1_idx_list.append(data_idx)
    
print(len(conv1_idx_list))



pool1_idx_list=[]
for pool1_idx in range(0,len(conv1_idx_list)-(pool1_size-1), pool1_stride):
    temp_idx = []
    for conv1_idx in np.arange(max(pool1_idx,0), min(pool1_idx+pool1_size ,len(conv1_idx_list))):
        temp_idx.extend(conv1_idx_list[conv1_idx])
    if set(temp_idx):
        pool1_idx_list.append(list(set(temp_idx)))
        
if (pool1_idx + pool1_size) < (len(conv1_idx_list)-1):
    temp_idx = []
    for conv1_idx in np.arange(pool1_idx+1, len(conv1_idx_list)):
        temp_idx.extend(conv1_idx_list[conv1_idx])
        pool1_idx_list.append(list(set(temp_idx)))
print(len(pool1_idx_list))


conv2_idx_list=[]
for conv2_idx in range(0,len(pool1_idx_list), conv2_stride):
    temp_idx = []
    for pool1_idx in np.arange(max(conv2_idx-(conv2_size//2),0), min(conv2_idx+(conv2_size//2) +1 ,len(pool1_idx_list))):
        temp_idx.extend(pool1_idx_list[pool1_idx])
    if set(temp_idx):
        conv2_idx_list.append(list(set(temp_idx)))

if conv2_idx < (len(pool1_idx_list)-1):
    print("add")
    temp_idx = []
    for pool1_idx in np.arange(conv2_idx+1, len(pool1_idx_list)):
        conv2_idx_list.append(pool1_idx_list[pool1_idx])
print(len(conv2_idx_list))




pool2_idx_list=[]
for pool2_idx in range(0,len(conv2_idx_list)-(pool2_size-1), pool2_stride):
    temp_idx = []
    for conv2_idx in np.arange(max(pool2_idx ,0), min(pool2_idx+pool2_size ,len(conv2_idx_list))):
        temp_idx.extend(conv2_idx_list[conv2_idx])
    pool2_idx_list.append(list(set(temp_idx)))

if (pool2_idx + pool2_size-1) < (len(conv2_idx_list)-1):
    print('add')
    temp_idx = []
    for conv2_idx in np.arange(pool2_idx+ pool2_size+1, len(conv2_idx_list)):
        pool2_idx_list.append(conv2_idx_list[conv2_idx])
print(len(pool2_idx_list))

conv3_idx_list=[]
for conv3_idx in range(0,len(pool2_idx_list), conv3_stride):
    temp_idx = []
    for pool2_idx in np.arange(max(conv3_idx-(conv3_size//2),0), min(conv3_idx+(conv3_size//2) +1 ,len(pool2_idx_list))):
        temp_idx.extend(pool2_idx_list[pool2_idx])
    if set(temp_idx):
        conv3_idx_list.append(list(set(temp_idx)))

if conv3_idx < (len(pool2_idx_list)-1):
    print("add")
    temp_idx = []
    for pool2_idx in np.arange(conv3_idx+1, len(pool3_idx_list)):
        conv3_idx_list.append(pool2_idx_list[pool2_idx])
print(len(conv3_idx_list))



pool3_idx_list=[]
for pool3_idx in range(0,len(conv3_idx_list)-(pool3_size-1), pool3_stride):
    temp_idx = []
    for conv3_idx in np.arange(max(pool3_idx ,0), min(pool3_idx+pool3_size ,len(conv3_idx_list))):
        temp_idx.extend(conv3_idx_list[conv3_idx])
    pool3_idx_list.append(list(set(temp_idx)))

if (pool3_idx + pool3_size-1) < (len(conv3_idx_list)-1):
    print('add')
    for conv3_idx in np.arange(pool3_idx+ pool3_size+1, len(conv3_idx_list)):
        pool3_idx_list.append(conv3_idx_list[conv3_idx])
print(len(pool3_idx_list))
# Out:
# 473
# 117
# 117
# add
# 57
# 57
# add
# 27

# %%
pool1_pattern_len = np.max([len(x) for x in pool1_idx_list])
pool2_pattern_len = np.max([len(x) for x in pool2_idx_list])
pool3_pattern_len = np.max([len(x) for x in pool3_idx_list])

print("pool pattern length : pool1({}),pool2({}),pool3({})".format(pool1_pattern_len,
                                                                     pool2_pattern_len,
                                                                     pool3_pattern_len))
# Out:
# pool pattern length : pool1(29),pool2(133),pool3(277)

# %%
pool1_output_len = len(pool1_idx_list)
pool2_output_len = len(pool2_idx_list)
pool3_output_len = len(pool3_idx_list)

# %%
pool1_output_len
# Out:
# 117

# %%
tf.reset_default_graph()

# %%
#if 'MC_dropout_model' in globals()
try:
    MC_dropout_model.sess.close()
except:
    pass
tf.reset_default_graph()
MC_dropout_model = conv3_basic_CNN(featuremap1=pool1_output_len, featuremap2=pool2_output_len, featuremap3=pool3_output_len,
                                      conv1_size=conv1_size, conv2_size=conv2_size, conv3_size=conv3_size,
                                      conv1_channel=conv1_channel, conv2_channel=conv2_channel, conv3_channel=conv3_channel,
                                       conv1_stride=conv1_stride, conv2_stride=conv2_stride, conv3_stride=conv3_stride,
                                       pool1_size=pool1_size, pool2_size=pool2_size, pool3_size=pool3_size,
                                       pool1_stride=pool1_stride, pool2_stride=pool2_stride, pool3_stride=pool3_stride,
                                       
                                      height=height,width= width, input_channel=input_channel ,nb_classes=nb_classes,
                                 std=std,batch_size=batch_size,l_rate=l_rate)

# %%
print (MC_dropout_model.reshaped_input)

print ('[layer1] - MC dropout')
print (MC_dropout_model.conv1)
print (MC_dropout_model.pool1)
print (MC_dropout_model.relu1)
print (MC_dropout_model.dropout1)
print ('[layer2] - MC dropout')
print (MC_dropout_model.conv2)
print (MC_dropout_model.pool2)
print (MC_dropout_model.relu2)
print (MC_dropout_model.dropout2)
print ('[layer3] - MC dropout')
print (MC_dropout_model.conv3)
print (MC_dropout_model.pool3)
print (MC_dropout_model.relu3)
print (MC_dropout_model.dropout3)


print ('[layer4]')
print (MC_dropout_model.reshaped)
print (MC_dropout_model.y)
# Out:
# Tensor("layer0/absolute_input:0", shape=(?, 1, 945, 1), dtype=float32)
# [layer1] - MC dropout
# Tensor("layer1/Conv2D:0", shape=(?, 1, 473, 32), dtype=float32)
# Tensor("layer1/MaxPool:0", shape=(?, 1, 117, 32), dtype=float32)
# Tensor("layer1/Relu:0", shape=(?, 1, 473, 32), dtype=float32)
# Tensor("layer1/dropout/mul:0", shape=(?, 1, 117, 32), dtype=float32)
# [layer2] - MC dropout
# Tensor("layer2/Conv2D:0", shape=(?, 1, 117, 64), dtype=float32)
# Tensor("layer2/MaxPool:0", shape=(?, 1, 57, 64), dtype=float32)
# Tensor("layer2/Relu:0", shape=(?, 1, 117, 64), dtype=float32)
# Tensor("layer2/dropout/mul:0", shape=(?, 1, 57, 64), dtype=float32)
# [layer3] - MC dropout
# Tensor("layer3/Conv2D:0", shape=(?, 1, 57, 128), dtype=float32)
# Tensor("layer3/MaxPool:0", shape=(?, 1, 27, 128), dtype=float32)
# Tensor("layer3/Relu:0", shape=(?, 1, 57, 128), dtype=float32)
# Tensor("layer3/dropout/mul:0", shape=(?, 1, 27, 128), dtype=float32)
# [layer4]
# Tensor("layer4/Reshape:0", shape=(?, 3456), dtype=float32)
# Tensor("layer4/absolute_output:0", shape=(?, 8), dtype=float32)

# %% [markdown]
# # 4. Training

# %%
import time
import os
import numpy as np

# %%
save_path = './model/'+data_name
model_name = data_name+"_CNN_conv3_"+str(l_rate)+'_'+str(batch_size)
print (model_name)
# Out:
# UWaveGestureLibraryAll_CNN_conv3_1e-05_64

# %%
from training import get_batch

# %%
keep_prob =1.0

# %%
trainY.shape
# Out:
# (3582, 8)

# %%
for epoch in range(num_epochs):#range(num_epochs):##
    
    loss = 0
    acc=0
    train_batches = 0
    start_time = time.time()   
    
    for batch in get_batch(X=trainX, Y=trainY, nb_classes = nb_classes, batch_size=batch_size):
        train_in, train_target = batch
        train_batches += 1.0 
        loss1 ,acc1 = MC_dropout_model.train(data=train_in,target= train_target,keep_prob=keep_prob)
        loss = loss1+loss
        acc = acc1+acc
        if np.isnan(loss):
            print ('error')
            break
    t_loss.append(loss/train_batches)
    t_acc.append(acc/train_batches)
    
    train_history.loc[epoch] = [epoch, t_loss[epoch], t_acc[epoch] ,time.strftime("%Y-%m-%d-%H:%M", time.localtime())]
    if not os.path.exists(os.path.join(save_path, model_name)):
        os.mkdir( os.path.join(save_path, model_name))
    MC_dropout_model.save(os.path.join(save_path, model_name,str(epoch+1)+'.ckpt'))

    
    if(epoch+1)%val_freq ==0:
        acc=0
        loss = 0
        val_batches=0
        for batch in get_batch(X=validX, Y=validY, nb_classes = nb_classes, batch_size=batch_size):
            val_in, val_target = batch
            val_batches += 1.0 
            loss1 ,acc1 = MC_dropout_model.test(data=val_in,target= val_target,keep_prob=keep_prob)                                              
            loss = loss1+loss
            acc = acc1+acc
        
        v_acc.append(acc/val_batches)
        v_loss.append(loss/val_batches)
        valid_history.loc[epoch] = [epoch, v_loss[epoch], v_acc[epoch] ,time.strftime("%Y-%m-%d-%H:%M", time.localtime())]  
        
        print("  training loss:\t{:.6f}".format(t_loss[epoch]))
        print("  training acc:\t{:.3f}".format(t_acc[epoch]))
        print("  validation loss:\t{:.6f}".format(v_loss[epoch]))
        print("  validation acc:\t{:.3f}".format(v_acc[epoch]))
# Out:
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/1.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/1.ckpt
#   training loss:	2.160237
#   training acc:	0.158
#   validation loss:	2.057154
#   validation acc:	0.177
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/2.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/2.ckpt
#   training loss:	1.969638
#   training acc:	0.231
#   validation loss:	1.891757
#   validation acc:	0.315
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/3.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/3.ckpt
#   training loss:	1.815173
#   training acc:	0.438
#   validation loss:	1.738781
#   validation acc:	0.508
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/4.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/4.ckpt
#   training loss:	1.662790
#   training acc:	0.600
#   validation loss:	1.581552
#   validation acc:	0.620
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/5.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/5.ckpt
#   training loss:	1.502652
#   training acc:	0.704
#   validation loss:	1.416446
#   validation acc:	0.706
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/6.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/6.ckpt
#   training loss:	1.337299
#   training acc:	0.768
#   validation loss:	1.249887
#   validation acc:	0.763
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/7.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/7.ckpt
#   training loss:	1.174447
#   training acc:	0.806
#   validation loss:	1.090588
#   validation acc:	0.805
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/8.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/8.ckpt
#   training loss:	1.023136
#   training acc:	0.831
#   validation loss:	0.946816
#   validation acc:	0.812
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/9.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/9.ckpt
#   training loss:	0.888555
#   training acc:	0.848
#   validation loss:	0.821443
#   validation acc:	0.849
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/10.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/10.ckpt
#   training loss:	0.774090
#   training acc:	0.865
#   validation loss:	0.717560
#   validation acc:	0.859
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/11.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/11.ckpt
#   training loss:	0.681075
#   training acc:	0.873
#   validation loss:	0.633754
#   validation acc:	0.872
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/12.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/12.ckpt
#   training loss:	0.606714
#   training acc:	0.883
#   validation loss:	0.566972
#   validation acc:	0.878
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/13.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/13.ckpt
#   training loss:	0.547162
#   training acc:	0.889
#   validation loss:	0.513435
#   validation acc:	0.885
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/14.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/14.ckpt
#   training loss:	0.498923
#   training acc:	0.894
#   validation loss:	0.469976
#   validation acc:	0.891
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/15.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/15.ckpt
#   training loss:	0.459296
#   training acc:	0.899
#   validation loss:	0.434223
#   validation acc:	0.901
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/16.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/16.ckpt
#   training loss:	0.426217
#   training acc:	0.904
#   validation loss:	0.404294
#   validation acc:	0.901
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/17.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/17.ckpt
#   training loss:	0.398302
#   training acc:	0.908
#   validation loss:	0.379183
#   validation acc:	0.906
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/18.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/18.ckpt
#   training loss:	0.374419
#   training acc:	0.911
#   validation loss:	0.357754
#   validation acc:	0.917
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/19.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/19.ckpt
#   training loss:	0.353788
#   training acc:	0.916
#   validation loss:	0.339251
#   validation acc:	0.922
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/20.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/20.ckpt
#   training loss:	0.335683
#   training acc:	0.918
#   validation loss:	0.323006
#   validation acc:	0.922
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/21.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/21.ckpt
#   training loss:	0.319560
#   training acc:	0.921
#   validation loss:	0.308612
#   validation acc:	0.927
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/22.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/22.ckpt
#   training loss:	0.305106
#   training acc:	0.925
#   validation loss:	0.295559
#   validation acc:	0.927
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/23.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/23.ckpt
#   training loss:	0.292031
#   training acc:	0.927
#   validation loss:	0.283629
#   validation acc:	0.927
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/24.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/24.ckpt
#   training loss:	0.280134
#   training acc:	0.930
#   validation loss:	0.272772
#   validation acc:	0.932
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/25.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/25.ckpt
#   training loss:	0.269182
#   training acc:	0.932
#   validation loss:	0.262907
#   validation acc:	0.935
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/26.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/26.ckpt
#   training loss:	0.259092
#   training acc:	0.935
#   validation loss:	0.253591
#   validation acc:	0.938
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/27.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/27.ckpt
#   training loss:	0.249798
#   training acc:	0.937
#   validation loss:	0.244863
#   validation acc:	0.940
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/28.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/28.ckpt
#   training loss:	0.241153
#   training acc:	0.939
#   validation loss:	0.236744
#   validation acc:	0.938
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/29.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/29.ckpt
#   training loss:	0.233089
#   training acc:	0.941
#   validation loss:	0.229200
#   validation acc:	0.938
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/30.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/30.ckpt
#   training loss:	0.225562
#   training acc:	0.943
#   validation loss:	0.222129
#   validation acc:	0.938
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/31.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/31.ckpt
#   training loss:	0.218517
#   training acc:	0.945
#   validation loss:	0.215631
#   validation acc:	0.943
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/32.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/32.ckpt
#   training loss:	0.211915
#   training acc:	0.947
#   validation loss:	0.209512
#   validation acc:	0.945
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/33.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/33.ckpt
#   training loss:	0.205728
#   training acc:	0.947
#   validation loss:	0.203833
#   validation acc:	0.945
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/34.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/34.ckpt
#   training loss:	0.199899
#   training acc:	0.950
#   validation loss:	0.198414
#   validation acc:	0.948
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/35.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/35.ckpt
#   training loss:	0.194404
#   training acc:	0.952
#   validation loss:	0.193322
#   validation acc:	0.951
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/36.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/36.ckpt
#   training loss:	0.189215
#   training acc:	0.953
#   validation loss:	0.188576
#   validation acc:	0.953
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/37.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/37.ckpt
#   training loss:	0.184285
#   training acc:	0.955
#   validation loss:	0.184094
#   validation acc:	0.953
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/38.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/38.ckpt
#   training loss:	0.179586
#   training acc:	0.956
#   validation loss:	0.179859
#   validation acc:	0.956
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/39.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/39.ckpt
#   training loss:	0.175113
#   training acc:	0.957
#   validation loss:	0.175855
#   validation acc:	0.956
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/40.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/40.ckpt
#   training loss:	0.170833
#   training acc:	0.958
#   validation loss:	0.171996
#   validation acc:	0.956
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/41.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/41.ckpt
#   training loss:	0.166739
#   training acc:	0.959
#   validation loss:	0.168368
#   validation acc:	0.956
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/42.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/42.ckpt
#   training loss:	0.162809
#   training acc:	0.960
#   validation loss:	0.164917
#   validation acc:	0.958
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/43.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/43.ckpt
#   training loss:	0.159023
#   training acc:	0.962
#   validation loss:	0.161708
#   validation acc:	0.961
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/44.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/44.ckpt
#   training loss:	0.155406
#   training acc:	0.962
#   validation loss:	0.158692
#   validation acc:	0.961
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/45.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/45.ckpt
#   training loss:	0.151953
#   training acc:	0.963
#   validation loss:	0.155808
#   validation acc:	0.961
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/46.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/46.ckpt
#   training loss:	0.148628
#   training acc:	0.964
#   validation loss:	0.153093
#   validation acc:	0.961
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/47.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/47.ckpt
#   training loss:	0.145439
#   training acc:	0.964
#   validation loss:	0.150503
#   validation acc:	0.961
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/48.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/48.ckpt
#   training loss:	0.142373
#   training acc:	0.966
#   validation loss:	0.148024
#   validation acc:	0.961
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/49.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/49.ckpt
#   training loss:	0.139412
#   training acc:	0.966
#   validation loss:	0.145689
#   validation acc:	0.961
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/50.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/50.ckpt
#   training loss:	0.136563
#   training acc:	0.967
#   validation loss:	0.143463
#   validation acc:	0.961
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/51.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/51.ckpt
#   training loss:	0.133829
#   training acc:	0.968
#   validation loss:	0.141360
#   validation acc:	0.961
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/52.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/52.ckpt
#   training loss:	0.131200
#   training acc:	0.968
#   validation loss:	0.139374
#   validation acc:	0.961
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/53.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/53.ckpt
#   training loss:	0.128666
#   training acc:	0.969
#   validation loss:	0.137474
#   validation acc:	0.964
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/54.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/54.ckpt
#   training loss:	0.126221
#   training acc:	0.969
#   validation loss:	0.135645
#   validation acc:	0.966
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/55.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/55.ckpt
#   training loss:	0.123846
#   training acc:	0.970
#   validation loss:	0.133967
#   validation acc:	0.966
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/56.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/56.ckpt
#   training loss:	0.121543
#   training acc:	0.970
#   validation loss:	0.132336
#   validation acc:	0.966
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/57.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/57.ckpt
#   training loss:	0.119321
#   training acc:	0.970
#   validation loss:	0.130810
#   validation acc:	0.966
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/58.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/58.ckpt
#   training loss:	0.117178
#   training acc:	0.971
#   validation loss:	0.129371
#   validation acc:	0.966
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/59.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/59.ckpt
#   training loss:	0.115105
#   training acc:	0.971
#   validation loss:	0.128010
#   validation acc:	0.966
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/60.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/60.ckpt
#   training loss:	0.113098
#   training acc:	0.972
#   validation loss:	0.126715
#   validation acc:	0.966
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/61.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/61.ckpt
#   training loss:	0.111145
#   training acc:	0.973
#   validation loss:	0.125495
#   validation acc:	0.966
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/62.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/62.ckpt
#   training loss:	0.109245
#   training acc:	0.973
#   validation loss:	0.124320
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/63.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/63.ckpt
#   training loss:	0.107385
#   training acc:	0.974
#   validation loss:	0.123187
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/64.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/64.ckpt
#   training loss:	0.105564
#   training acc:	0.974
#   validation loss:	0.122078
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/65.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/65.ckpt
#   training loss:	0.103790
#   training acc:	0.974
#   validation loss:	0.121009
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/66.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/66.ckpt
#   training loss:	0.102069
#   training acc:	0.974
#   validation loss:	0.119957
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/67.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/67.ckpt
#   training loss:	0.100388
#   training acc:	0.974
#   validation loss:	0.118941
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/68.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/68.ckpt
#   training loss:	0.098752
#   training acc:	0.975
#   validation loss:	0.117985
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/69.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/69.ckpt
#   training loss:	0.097150
#   training acc:	0.975
#   validation loss:	0.117047
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/70.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/70.ckpt
#   training loss:	0.095588
#   training acc:	0.975
#   validation loss:	0.116146
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/71.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/71.ckpt
#   training loss:	0.094064
#   training acc:	0.976
#   validation loss:	0.115272
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/72.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/72.ckpt
#   training loss:	0.092574
#   training acc:	0.976
#   validation loss:	0.114447
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/73.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/73.ckpt
#   training loss:	0.091110
#   training acc:	0.976
#   validation loss:	0.113638
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/74.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/74.ckpt
#   training loss:	0.089674
#   training acc:	0.976
#   validation loss:	0.112838
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/75.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/75.ckpt
#   training loss:	0.088262
#   training acc:	0.976
#   validation loss:	0.112046
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/76.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/76.ckpt
#   training loss:	0.086880
#   training acc:	0.976
#   validation loss:	0.111318
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/77.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/77.ckpt
#   training loss:	0.085534
#   training acc:	0.976
#   validation loss:	0.110617
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/78.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/78.ckpt
#   training loss:	0.084213
#   training acc:	0.976
#   validation loss:	0.109963
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/79.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/79.ckpt
#   training loss:	0.082921
#   training acc:	0.977
#   validation loss:	0.109325
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/80.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/80.ckpt
#   training loss:	0.081652
#   training acc:	0.977
#   validation loss:	0.108735
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/81.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/81.ckpt
#   training loss:	0.080402
#   training acc:	0.977
#   validation loss:	0.108162
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/82.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/82.ckpt
#   training loss:	0.079165
#   training acc:	0.978
#   validation loss:	0.107585
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/83.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/83.ckpt
#   training loss:	0.077962
#   training acc:	0.979
#   validation loss:	0.107065
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/84.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/84.ckpt
#   training loss:	0.076776
#   training acc:	0.979
#   validation loss:	0.106572
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/85.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/85.ckpt
#   training loss:	0.075621
#   training acc:	0.979
#   validation loss:	0.106073
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/86.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/86.ckpt
#   training loss:	0.074490
#   training acc:	0.979
#   validation loss:	0.105604
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/87.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/87.ckpt
#   training loss:	0.073379
#   training acc:	0.980
#   validation loss:	0.105147
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/88.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/88.ckpt
#   training loss:	0.072291
#   training acc:	0.980
#   validation loss:	0.104726
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/89.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/89.ckpt
#   training loss:	0.071225
#   training acc:	0.980
#   validation loss:	0.104328
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/90.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/90.ckpt
#   training loss:	0.070171
#   training acc:	0.980
#   validation loss:	0.103934
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/91.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/91.ckpt
#   training loss:	0.069136
#   training acc:	0.980
#   validation loss:	0.103553
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/92.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/92.ckpt
#   training loss:	0.068114
#   training acc:	0.981
#   validation loss:	0.103143
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/93.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/93.ckpt
#   training loss:	0.067117
#   training acc:	0.982
#   validation loss:	0.102754
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/94.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/94.ckpt
#   training loss:	0.066136
#   training acc:	0.982
#   validation loss:	0.102378
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/95.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/95.ckpt
#   training loss:	0.065168
#   training acc:	0.983
#   validation loss:	0.101982
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/96.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/96.ckpt
#   training loss:	0.064219
#   training acc:	0.983
#   validation loss:	0.101579
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/97.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/97.ckpt
#   training loss:	0.063286
#   training acc:	0.983
#   validation loss:	0.101212
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/98.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/98.ckpt
#   training loss:	0.062377
#   training acc:	0.984
#   validation loss:	0.100850
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/99.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/99.ckpt
#   training loss:	0.061481
#   training acc:	0.984
#   validation loss:	0.100478
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/100.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/100.ckpt
#   training loss:	0.060597
#   training acc:	0.984
#   validation loss:	0.100122
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/101.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/101.ckpt
#   training loss:	0.059727
#   training acc:	0.985
#   validation loss:	0.099765
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/102.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/102.ckpt
#   training loss:	0.058872
#   training acc:	0.986
#   validation loss:	0.099418
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/103.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/103.ckpt
#   training loss:	0.058030
#   training acc:	0.986
#   validation loss:	0.099116
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/104.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/104.ckpt
#   training loss:	0.057206
#   training acc:	0.986
#   validation loss:	0.098796
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/105.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/105.ckpt
#   training loss:	0.056391
#   training acc:	0.986
#   validation loss:	0.098474
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/106.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/106.ckpt
#   training loss:	0.055585
#   training acc:	0.987
#   validation loss:	0.098144
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/107.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/107.ckpt
#   training loss:	0.054793
#   training acc:	0.987
#   validation loss:	0.097822
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/108.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/108.ckpt
#   training loss:	0.054009
#   training acc:	0.987
#   validation loss:	0.097479
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/109.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/109.ckpt
#   training loss:	0.053245
#   training acc:	0.987
#   validation loss:	0.097179
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/110.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/110.ckpt
#   training loss:	0.052487
#   training acc:	0.988
#   validation loss:	0.096887
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/111.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/111.ckpt
#   training loss:	0.051738
#   training acc:	0.988
#   validation loss:	0.096601
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/112.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/112.ckpt
#   training loss:	0.050993
#   training acc:	0.988
#   validation loss:	0.096359
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/113.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/113.ckpt
#   training loss:	0.050258
#   training acc:	0.988
#   validation loss:	0.096085
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/114.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/114.ckpt
#   training loss:	0.049530
#   training acc:	0.988
#   validation loss:	0.095855
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/115.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/115.ckpt
#   training loss:	0.048825
#   training acc:	0.988
#   validation loss:	0.095596
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/116.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/116.ckpt
#   training loss:	0.048125
#   training acc:	0.988
#   validation loss:	0.095339
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/117.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/117.ckpt
#   training loss:	0.047438
#   training acc:	0.988
#   validation loss:	0.095107
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/118.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/118.ckpt
#   training loss:	0.046764
#   training acc:	0.988
#   validation loss:	0.094884
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/119.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/119.ckpt
#   training loss:	0.046097
#   training acc:	0.988
#   validation loss:	0.094674
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/120.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/120.ckpt
#   training loss:	0.045440
#   training acc:	0.988
#   validation loss:	0.094435
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/121.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/121.ckpt
#   training loss:	0.044792
#   training acc:	0.989
#   validation loss:	0.094204
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/122.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/122.ckpt
#   training loss:	0.044150
#   training acc:	0.989
#   validation loss:	0.094036
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/123.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/123.ckpt
#   training loss:	0.043520
#   training acc:	0.989
#   validation loss:	0.093829
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/124.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/124.ckpt
#   training loss:	0.042895
#   training acc:	0.989
#   validation loss:	0.093660
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/125.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/125.ckpt
#   training loss:	0.042271
#   training acc:	0.990
#   validation loss:	0.093456
#   validation acc:	0.974
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/126.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/126.ckpt
#   training loss:	0.041663
#   training acc:	0.991
#   validation loss:	0.093254
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/127.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/127.ckpt
#   training loss:	0.041060
#   training acc:	0.991
#   validation loss:	0.093049
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/128.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/128.ckpt
#   training loss:	0.040468
#   training acc:	0.991
#   validation loss:	0.092856
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/129.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/129.ckpt
#   training loss:	0.039881
#   training acc:	0.991
#   validation loss:	0.092649
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/130.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/130.ckpt
#   training loss:	0.039304
#   training acc:	0.991
#   validation loss:	0.092454
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/131.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/131.ckpt
#   training loss:	0.038733
#   training acc:	0.991
#   validation loss:	0.092282
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/132.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/132.ckpt
#   training loss:	0.038170
#   training acc:	0.991
#   validation loss:	0.092098
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/133.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/133.ckpt
#   training loss:	0.037611
#   training acc:	0.991
#   validation loss:	0.091909
#   validation acc:	0.971
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/134.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/134.ckpt
#   training loss:	0.037059
#   training acc:	0.991
#   validation loss:	0.091711
#   validation acc:	0.971
# ...
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/256.ckpt
#   training loss:	0.004582
#   training acc:	1.000
#   validation loss:	0.098635
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/257.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/257.ckpt
#   training loss:	0.004497
#   training acc:	1.000
#   validation loss:	0.098768
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/258.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/258.ckpt
#   training loss:	0.004413
#   training acc:	1.000
#   validation loss:	0.098899
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/259.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/259.ckpt
#   training loss:	0.004332
#   training acc:	1.000
#   validation loss:	0.099058
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/260.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/260.ckpt
#   training loss:	0.004252
#   training acc:	1.000
#   validation loss:	0.099176
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/261.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/261.ckpt
#   training loss:	0.004174
#   training acc:	1.000
#   validation loss:	0.099380
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/262.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/262.ckpt
#   training loss:	0.004097
#   training acc:	1.000
#   validation loss:	0.099520
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/263.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/263.ckpt
#   training loss:	0.004022
#   training acc:	1.000
#   validation loss:	0.099709
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/264.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/264.ckpt
#   training loss:	0.003948
#   training acc:	1.000
#   validation loss:	0.099905
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/265.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/265.ckpt
#   training loss:	0.003875
#   training acc:	1.000
#   validation loss:	0.100119
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/266.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/266.ckpt
#   training loss:	0.003804
#   training acc:	1.000
#   validation loss:	0.100251
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/267.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/267.ckpt
#   training loss:	0.003734
#   training acc:	1.000
#   validation loss:	0.100391
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/268.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/268.ckpt
#   training loss:	0.003664
#   training acc:	1.000
#   validation loss:	0.100567
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/269.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/269.ckpt
#   training loss:	0.003597
#   training acc:	1.000
#   validation loss:	0.100703
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/270.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/270.ckpt
#   training loss:	0.003529
#   training acc:	1.000
#   validation loss:	0.100859
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/271.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/271.ckpt
#   training loss:	0.003464
#   training acc:	1.000
#   validation loss:	0.101045
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/272.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/272.ckpt
#   training loss:	0.003400
#   training acc:	1.000
#   validation loss:	0.101169
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/273.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/273.ckpt
#   training loss:	0.003336
#   training acc:	1.000
#   validation loss:	0.101327
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/274.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/274.ckpt
#   training loss:	0.003274
#   training acc:	1.000
#   validation loss:	0.101466
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/275.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/275.ckpt
#   training loss:	0.003211
#   training acc:	1.000
#   validation loss:	0.101629
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/276.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/276.ckpt
#   training loss:	0.003152
#   training acc:	1.000
#   validation loss:	0.101743
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/277.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/277.ckpt
#   training loss:	0.003092
#   training acc:	1.000
#   validation loss:	0.101872
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/278.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/278.ckpt
#   training loss:	0.003035
#   training acc:	1.000
#   validation loss:	0.101999
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/279.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/279.ckpt
#   training loss:	0.002978
#   training acc:	1.000
#   validation loss:	0.102152
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/280.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/280.ckpt
#   training loss:	0.002922
#   training acc:	1.000
#   validation loss:	0.102257
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/281.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/281.ckpt
#   training loss:	0.002867
#   training acc:	1.000
#   validation loss:	0.102390
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/282.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/282.ckpt
#   training loss:	0.002813
#   training acc:	1.000
#   validation loss:	0.102583
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/283.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/283.ckpt
#   training loss:	0.002759
#   training acc:	1.000
#   validation loss:	0.102766
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/284.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/284.ckpt
#   training loss:	0.002706
#   training acc:	1.000
#   validation loss:	0.102956
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/285.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/285.ckpt
#   training loss:	0.002654
#   training acc:	1.000
#   validation loss:	0.103166
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/286.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/286.ckpt
#   training loss:	0.002604
#   training acc:	1.000
#   validation loss:	0.103376
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/287.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/287.ckpt
#   training loss:	0.002554
#   training acc:	1.000
#   validation loss:	0.103581
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/288.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/288.ckpt
#   training loss:	0.002506
#   training acc:	1.000
#   validation loss:	0.103784
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/289.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/289.ckpt
#   training loss:	0.002457
#   training acc:	1.000
#   validation loss:	0.104027
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/290.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/290.ckpt
#   training loss:	0.002410
#   training acc:	1.000
#   validation loss:	0.104235
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/291.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/291.ckpt
#   training loss:	0.002364
#   training acc:	1.000
#   validation loss:	0.104445
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/292.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/292.ckpt
#   training loss:	0.002319
#   training acc:	1.000
#   validation loss:	0.104635
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/293.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/293.ckpt
#   training loss:	0.002274
#   training acc:	1.000
#   validation loss:	0.104852
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/294.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/294.ckpt
#   training loss:	0.002231
#   training acc:	1.000
#   validation loss:	0.105067
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/295.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/295.ckpt
#   training loss:	0.002188
#   training acc:	1.000
#   validation loss:	0.105298
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/296.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/296.ckpt
#   training loss:	0.002146
#   training acc:	1.000
#   validation loss:	0.105518
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/297.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/297.ckpt
#   training loss:	0.002105
#   training acc:	1.000
#   validation loss:	0.105747
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/298.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/298.ckpt
#   training loss:	0.002065
#   training acc:	1.000
#   validation loss:	0.106001
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/299.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/299.ckpt
#   training loss:	0.002025
#   training acc:	1.000
#   validation loss:	0.106225
#   validation acc:	0.979
# INFO:tensorflow:./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/300.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/300.ckpt
#   training loss:	0.001986
#   training acc:	1.000
#   validation loss:	0.106464
#   validation acc:	0.979

# %%
train_history.to_csv(os.path.join(save_path,model_name,  "history_train.csv"))
valid_history.to_csv(os.path.join(save_path,model_name,  "history_valid.csv"))

# %% [markdown]
# # 5.check the result

# %% [markdown]
# ### with loss and accuracy graph

# %%
from visualization import plot_train_history

# %%
train_history = pd.read_csv(os.path.join(save_path,model_name,"history_train.csv"),index_col=0)
valid_history = pd.read_csv(os.path.join(save_path,model_name,"history_valid.csv"),index_col=0)

# %%
plot_train_history(train_df = train_history,
                   valid_df = valid_history,
                   save_path = os.path.join(save_path,model_name))
# Out:
# save ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/loss_graph.png
# save ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/acc_graph.png

# %%
bestepoch = int(np.argmin(valid_history['loss'].values))
print( bestepoch)

error = valid_history.loc[bestepoch,'loss']
print ("error: {}".format(error))

MC_dropout_model.load(os.path.join(save_path,model_name,str(bestepoch)+'.ckpt'))
# Out:
# 168
# error: 0.0880859587341547
# INFO:tensorflow:Restoring parameters from ./model/UWaveGestureLibraryAll/UWaveGestureLibraryAll_CNN_conv3_1e-05_64/168.ckpt
# Model restored

# %%
import glob
for epoch in [x+1 for x in range(num_epochs) if (x+1) !=bestepoch]:
    for filename in glob.glob(os.path.join(save_path,model_name,str(epoch)+".*")):
        os.remove(filename)

# %% [markdown]
# ### with confusion matrix

# %%
from visualization import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
class_list = np.unique(trainy, return_counts=False, return_index=True)[0].astype(int)

# %%
prediction = MC_dropout_model.predict(data=trainX,keep_prob=1.0)
prediction = np.argmax(prediction,axis=1)
target = np.argmax(trainY,axis=1)

plot_confusion_matrix(confusion_matrix(target,prediction),                      
    classes=class_list,
    title=data_name+'classifcation(train)')

# %%
prediction = MC_dropout_model.predict(data=testX,keep_prob=1.0)
prediction = np.argmax(prediction,axis=1)
target = np.argmax(testY,axis=1)

plot_confusion_matrix(confusion_matrix(target,prediction),                      
    classes=class_list,
    title=data_name+'classifcation(test)')

# %% [markdown]
# ## 클래스 정하기

# %%
pattern_class = [np.arange(1,nb_classes+1)]

# %% [markdown]
# ## pattern 추출

# %% [markdown]
# last_weight = MC_dropout_model.sess.run([tf.trainable_variables()[-2]],feed_dict={})

# %%
pattern_length = np.max([len(x) for x in pool1_idx_list])
reindexed_relu_bool=[]

relu_output = MC_dropout_model.get_output(output = MC_dropout_model.pool1,data=trainX,keep_prob=1.0)

relu_output = relu_output.reshape(-1,1,pool1_output_len,conv1_channel)
temp_threshold = np.percentile(relu_output,99.5,[0,1,2])
relu_bool = (relu_output>temp_threshold).squeeze()     


for p,data_idx in enumerate(range(len(trainX))):
    for output_c in range(conv1_channel):
        if len([x for x in relu_bool[p,:,output_c].flatten() if x]):
            index = []
            for idx in [i for i,x in enumerate(relu_bool[p,:,output_c].flatten()) if x]:    
                reindexed_relu_bool.append([data_idx,output_c,idx])

# %% [markdown]
# ### 패턴 중복 count

# %%
pattern_idx_df = pd.DataFrame(reindexed_relu_bool,columns=["data_idx","output_channel","pattern_xs"])
groups = pattern_idx_df.groupby(["data_idx","pattern_xs"])#["output_channel"].apply(list)
pattern_repetitive_idx_df = groups["output_channel"].apply(list).reset_index(name='output_channel')

# %%
pattern_repetitive_idx_df.head()
# Out:
#    data_idx  pattern_xs           output_channel
# 0         0          77           [3, 9, 18, 29]
# 1         0          78           [3, 9, 18, 29]
# 2         0          79                  [9, 18]
# 3         2          94                     [24]
# 4         2          95  [2, 12, 22, 24, 25, 26]

# %%
consecutive_pattern=[]
pattern_id=0

data_idx = pattern_repetitive_idx_df.loc[:,"data_idx"].values.tolist()
output_channel = pattern_repetitive_idx_df.loc[:,"output_channel"].values.tolist()
pattern_xs = pattern_repetitive_idx_df.loc[:,"pattern_xs"].values.tolist()

for d_idx, output_c,  p_xs in zip(data_idx, output_channel, pattern_xs):
    for input_c in range(trainX.shape[3]):
        pattern_dict={}
        pattern_dict["pattern_id"]= pattern_id
        pattern_dict["data_idx"] = d_idx
        pattern_dict["output_channel"] = output_c
        pattern_dict["input_channel"] = input_c
        pattern_dict["pattern_xs"]= pool1_idx_list[p_xs]

        short_pattern = pattern_length - len(trainX[d_idx,0,pool1_idx_list[p_xs],input_c])

        if short_pattern:
            if pool1_idx_list[p_xs][0]==0:
                extended_xs= np.concatenate((np.arange(-short_pattern,0),pool1_idx_list[p_xs]))
                pattern_dict["pattern_ys"] = np.concatenate((np.zeros(short_pattern),(trainX[d_idx,0,pool1_idx_list[p_xs],input_c])))
            else:
                pattern_dict["pattern_ys"] = np.concatenate((trainX[d_idx,0,pool1_idx_list[p_xs],input_c],np.zeros(short_pattern)))
        else:
            pattern_dict["pattern_ys"] = trainX[d_idx,0,pool1_idx_list[p_xs],input_c]

        consecutive_pattern.append(pattern_dict)
        pattern_id+=1

# %%
np.concatenate((np.arange(-3,0),np.asarray(pool1_idx_list[p_xs])))
# Out:
# array([ -3,  -2,  -1, 640, 641, 642, 643, 644, 645, 646, 647, 648, 649,
#        650, 651, 652, 653, 625, 626, 627, 628, 629, 630, 631, 632, 633,
#        634, 635, 636, 637, 638, 639])

# %%
# Out:
# [640,
#  641,
#  642,
#  643,
#  644,
#  645,
#  646,
#  647,
#  648,
#  649,
#  650,
#  651,
#  652,
#  653,
#  625,
#  626,
#  627,
#  628,
#  629,
#  630,
#  631,
#  632,
#  633,
#  634,
#  635,
#  636,
#  637,
#  638,
#  639]

# %%
n_cluster=30

# %%
main_title = "{},layer1,class{},cluster{}".format(data_name,pattern_class,n_cluster)
print(main_title)
# Out:
# UWaveGestureLibraryAll,layer1,class[array([1, 2, 3, 4, 5, 6, 7, 8])],cluster30

# %%
np.save('./pattern/{}-0.05%.npy'.format(main_title), consecutive_pattern)

# %%
consecutive_pattern = np.load('./pattern/{}-0.05%.npy'.format(main_title),allow_pickle=True)

# %%
pattern =[x['pattern_ys'] for x in consecutive_pattern]
pattern_weight = np.asarray([len(x['output_channel']) for x in consecutive_pattern])

# %%
len(pattern)
# Out:
# 9071

# %%
pattern_weight.max()
# Out:
# 25

# %% [markdown]
# pattern = np.asarray(pattern)[pattern_weight > np.quantile(pattern_weight,0.75)]
# consecutive_pattern = np.asarray(consecutive_pattern)[pattern_weight >np.quantile(pattern_weight,0.75)]
# pattern_weight = np.asarray(pattern_weight)[pattern_weight >np.quantile(pattern_weight,0.75)]

# %%
from sklearn import cluster, mixture

# %%
default_base = {'eps': .3,
            'n_clusters': n_cluster}

params = default_base.copy()

params['n_clusters']=n_cluster

k_means = cluster.MiniBatchKMeans(n_clusters=params['n_clusters'])
weighted_k_means = cluster.MiniBatchKMeans(n_clusters=params['n_clusters'])
gmm = mixture.GaussianMixture(
        n_components=params['n_clusters'], covariance_type='full')
#spectral = cluster.SpectralClustering(n_clusters=params['n_clusters'])
#spectral_n = cluster.SpectralClustering(n_clusters=params['n_clusters'],affinity='nearest_neighbor')

clustering_algorithms = (
    ('KMeans', k_means),
    ('MiniBatch_weighted_KMeans', weighted_k_means),
    ('GMM',gmm)
    #('Spectral_RBF', spectral),
    #('Spectral_NN', spectral_n),
    )

cluster_label_df = pd.DataFrame(index = range(0,len(pattern)))

# %%
import sklearn
sklearn.__version__
# Out:
# '0.21.3'

# %%
for name, algorithm in clustering_algorithms:
    print("{} fitting".format(name))
    if "weighted" in name:
        algorithm.fit(pattern,sample_weight= pattern_weight)
    #elif "Spectral" in name:
    #    algorithm.fit(pattern)
    else:
        algorithm.fit(pattern)

    if hasattr(algorithm, 'labels_'):
        vars()[str(name)+"_pred"] = algorithm.labels_.astype(np.int)
    else:
        vars()[str(name)+"_pred"] = algorithm.predict(pattern)

    cluster_label_df.loc[:,str(name)+"_label"] = eval(str(name)+"_pred")

cluster_label_df.to_csv('./pattern/{}_label'.format(main_title,n_cluster))
# Out:
# KMeans fitting
# MiniBatch_weighted_KMeans fitting
# GMM fitting

# %%
cluster_label_df= pd.read_csv('./pattern/{}_label'.format(main_title,n_cluster),index_col=0)

# %%
import random

# %%
from matplotlib.pyplot import cm

column=6
color = cm.rainbow(np.linspace(0,1,n_cluster))[::-1]

y_max = np.abs(max(np.min(pattern), np.max(pattern), key=abs))
y_min = -y_max 
cluster_group = []
for name,algorithm in clustering_algorithms:
    fig = plt.figure(figsize=(20,(n_cluster//6*3)))
    save_path = '{}_cluster_{}'.format(main_title, name)
    print("============================"+name+"============================")
    sort_idx = cluster_label_df[name+"_label"].value_counts()
    for n in range(n_cluster): 
        group_idx = [i for i,x in enumerate(eval(str(name)+"_pred")) if x == sort_idx.index[n]]
        group_pattern = np.array([pattern[idx] for idx in group_idx])
        group_pattern_mean = group_pattern.mean(axis=0)
        group_pattern_std = group_pattern.std(axis=0)
        
        if "weighted" in name:
            for c in group_idx:
                consecutive_pattern[c]["group"]=sort_idx.index[n]

            cluster_group.append({"group":sort_idx.index[n],"n":n,
                                 "color_idx":n,"mean":group_pattern_mean,"std":group_pattern_std})
            

        ax = plt.subplot(n_cluster//column,column,n+1)

        ax.plot(group_pattern[random.sample(range(len(group_pattern)),min(len(group_pattern),100))].T, color =color[n],alpha=0.6)
        ax.plot(group_pattern_mean, color ='black',alpha=1,linewidth=5)

        ax.set_title("{} cluster_{} : {}({:2.1f}%)".format(n, sort_idx.index[n],sort_idx.iloc[n],sort_idx.iloc[n]/len(pattern)*100))
        ax.set_ylim(y_min,y_max) 

    fig.suptitle(main_title,y=1.0,size=12)
    plt.tight_layout()
    plt.show()
    
    plt.savefig(os.path.join('./figure',save_path))
    print("{} saved at {}".format(main_title,os.path.join('./figure',save_path)))
    #plt.close()
# Out:
# ============================KMeans============================
# UWaveGestureLibraryAll,layer1,class[array([1, 2, 3, 4, 5, 6, 7, 8])],cluster30 saved at ./figure/UWaveGestureLibraryAll,layer1,class[array([1, 2, 3, 4, 5, 6, 7, 8])],cluster30_cluster_KMeans
# ============================MiniBatch_weighted_KMeans============================
# UWaveGestureLibraryAll,layer1,class[array([1, 2, 3, 4, 5, 6, 7, 8])],cluster30 saved at ./figure/UWaveGestureLibraryAll,layer1,class[array([1, 2, 3, 4, 5, 6, 7, 8])],cluster30_cluster_MiniBatch_weighted_KMeans
# ============================GMM============================
# UWaveGestureLibraryAll,layer1,class[array([1, 2, 3, 4, 5, 6, 7, 8])],cluster30 saved at ./figure/UWaveGestureLibraryAll,layer1,class[array([1, 2, 3, 4, 5, 6, 7, 8])],cluster30_cluster_GMM

# %%
from matplotlib.pyplot import cm

column=6
color = cm.rainbow(np.linspace(0,1,n_cluster))[::-1]

y_max = np.abs(max(np.min(pattern), np.max(pattern), key=abs))
y_min = -y_max 
    
for name,algorithm in clustering_algorithms:
    fig = plt.figure(figsize=(20,(n_cluster//6*3)))
    save_path = '{}_{}_DROPOUT_relu3_cluster{}'.format(name,data_name, n_cluster)
    print("============================"+name+"============================")
    sort_idx = cluster_label_df[name+"_label"].value_counts()
    for n in range(n_cluster): 
        class_idx = [i for i,x in enumerate(eval(str(name)+"_pred")) if x == sort_idx.index[n]]
        class_pattern = np.array([pattern[idx] for idx in class_idx])
        class_pattern_mean = class_pattern.mean(axis=0)

        ax = plt.subplot(n_cluster//column,column,n+1)
        ax.plot(class_pattern_mean, color =color[n],alpha=1,linewidth=5)

        ax.set_title("{} cluster_{} : {}({:2.1f}%)".format(n, sort_idx.index[n],sort_idx.iloc[n],sort_idx.iloc[n]/len(pattern)*100))
        ax.set_ylim(y_min,y_max) 

    fig.suptitle(main_title,y=1.0,size=12)
    plt.tight_layout()
    plt.show()
    
    #plt.savefig(os.path.join('./figure',save_path))
    #print("{} saved at {}".format(main_title,os.path.join('./figure',save_path)))
    #plt.close()
# Out:
# ============================KMeans============================
# ============================MiniBatch_weighted_KMeans============================
# ============================GMM============================

# %% [markdown]
# # unit - pattern set matching with uncertainty measure

# %%
from collections import Counter

# %%
import os

# %% [markdown]
# unit_pattern_freq = np.asarray([None]*(n_cluster*conv3_channel)).reshape(conv3_channel, n_cluster)
# unit_pattern_std = np.asarray([None]*(n_cluster*conv3_channel)).reshape(conv3_channel, n_cluster)
#
# for unit_idx, mc_idx, cluster in zip(conv3_idxs, mc_idxs,cluster_idxs):
#     temp=[None]*n_cluster
#     temp_idx= [i for i,x in enumerate(consecutive_pattern) if ((mc_idx,unit_idx) in x['output_channel'])]
#
#     pattern_freq = Counter(cluster_label_df.iloc[:,1].values[temp_idx])
#     if pattern_freq[cluster]:
#         try:
#             temp[cluster].append(pattern_freq[cluster])
#         except :
#             temp[cluster]=[pattern_freq[cluster]]
#
#     unit_pattern_freq[unit_idx] = [np.mean(x) for x in temp]
#     unit_pattern_std[unit_idx] = [np.std(x) for x in temp]
#
#     print (unit_idx)

# %%
unit_pattern_freq = np.asarray([None]*(n_cluster*conv1_channel)).reshape(conv1_channel, n_cluster)
unit_pattern_std = np.asarray([None]*(n_cluster*conv1_channel)).reshape(conv1_channel, n_cluster)

for unit_idx in range(conv1_channel):  
    temp=[None]*n_cluster
    temp_idx= [i for i,x in enumerate(consecutive_pattern) if unit_idx in x['output_channel']]
    pattern_freq = Counter(cluster_label_df.iloc[:,1].values[temp_idx])
    for cluster in range(n_cluster):
        try:
            temp[cluster].append(pattern_freq[cluster])
        except : 
            temp[cluster]=[pattern_freq[cluster]]
    
    unit_pattern_freq[unit_idx] = [np.mean(x) for x in temp]
    unit_pattern_std[unit_idx] = [np.std(x) for x in temp]
# Out:
#   File "<ipython-input-139-79832960275f>", line 6
#     temp_idx= [i for i,x in enumerate(consecutive_pattern) if unit_idx in x['output_channel'])]
#                                                                                              ^
# SyntaxError: invalid syntax

# %%
unit_pattern_freq_df = pd.DataFrame(unit_pattern_freq)
unit_pattern_std_df = pd.DataFrame(unit_pattern_std)
unit_pattern_freq_df.to_csv('./pattern/{}_unitpattern_freq.csv'.format(main_title))
unit_pattern_std_df.to_csv('./pattern/{}_unitpattern_std.csv'.format(main_title))

# %%
unit_pattern_freq_df =pd.read_csv('./pattern/{}_unitpattern_freq.csv'.format(main_title),index_col=0)
unit_pattern_std_df =pd.read_csv('./pattern/{}_unitpattern_std.csv'.format(main_title),index_col=0)

# %%
many_freq_unit_pattern =  unit_pattern_freq_df.values > np.quantile(np.asarray(unit_pattern_freq_df),0.9,0)

# %%
plt.imshow(many_freq_unit_pattern, vmin=0, vmax=1,aspect='auto')

# %% [markdown]
# less_uncetainty_unit_pattern =  unit_pattern_std_df.values < np.quantile(np.asarray(unit_pattern_std_df),0.25,0)

# %% [markdown]
# plt.imshow(less_uncetainty_unit_pattern, vmin=0, vmax=1,aspect='auto')

# %% [markdown]
# general_unit_pattern = (many_freq_unit_pattern )# & less_uncetainty_unit_pattern)

# %%
focus_unit =[i for i,x in enumerate(many_freq_unit_pattern.sum(axis=1)>0) if x]
im = plt.imshow(many_freq_unit_pattern[focus_unit],interpolation='none', vmin=0, vmax=1, aspect='0.9');

ax = plt.gca();
ax.set_xticks(np.arange(0, n_cluster, 1));
ax.set_yticks(np.arange(0, len(focus_unit) , 1));
ax.set_xticklabels(np.arange(1,n_cluster+1, 1));
ax.set_yticklabels(focus_unit);

# Minor ticks
ax.set_xticks(np.arange(-.5, n_cluster-1, 1), minor=True);
ax.set_yticks(np.arange(-.5, len(focus_unit)-1, 1), minor=True);
ax.grid(which='minor', color='w', linestyle='-', linewidth=0.9)

# %% [markdown]
#  # Evaluation of unit-pattern set by IOU score

# %%
reindexed_relu_bool3=[]

relu_output3 = MC_dropout_model.get_output(output = MC_dropout_model.flatten,
                                                data=class_data,
                                                       keep_prob=1.0,
                                                       threshold_weight1 = np.tile(true_threshold_weight1,len(class_data)).T,
                                                       threshold_weight2 = np.tile(true_threshold_weight2,len(class_data)).T,
                                                       threshold_weight3 = np.tile(true_threshold_weight3,len(class_data)).T)

weighted_output3 = np.multiply(np.asarray(last_weight).squeeze().T[pattern_class-1], relu_output3)
relu_output3 = weighted_output3.reshape(-1,1,pool3_output_len,conv3_channel)
temp_threshold3 = np.percentile(dropout_relu_output3,99.5,[0,1,2])

relu_bool3 = (relu_output3>temp_threshold3).squeeze()   
    
for data_idx in range(len(class_data)):
    for output_c in range(conv3_channel):
        if len([x for x in relu_bool3[data_idx,:,output_c].flatten() if x]):
            index = []
            for idx in [i for i,x in enumerate(relu_bool3[data_idx,:,output_c].flatten()) if x]:    
                reindexed_relu_bool3.append([data_idx,(mc_idx,output_c),idx])

# %% [markdown]
# # 인풋 넣어서 IOU 계산

# %%
sample_data_idx = [5]

# %%
fig = plt.figure(figsize=(20,5))
plt.rcParams['axes.grid'] = False

ax = plt.subplot(1,2,1)
ax.imshow(relu_output3[sample_data_idx].T.squeeze(),aspect='auto')

ax = plt.subplot(1,2,2)
ax.imshow(relu_bool3[sample_data_idx].T.squeeze(),aspect='auto',vmin=0,vmax=1)
fig.suptitle("CONV3 OUTPUT\nthreshold: top{}%".format(0.05))

# %% [markdown]
# ## pattern 추출

# %% [markdown]
# ### reindexing1

# %%
pattern_length = np.max([len(x) for x in pool3_idx_list])

# %%
reindexed_relu_bool3=[]

for data_idx in sample_data_idx:
    for output_c in range(conv3_channel):
        if len([x for x in relu_bool3[data_idx,:,output_c].flatten() if x]):
            index = []
            for idx in [i for i,x in enumerate(relu_bool3[data_idx,:,output_c].flatten()) if x]:    
                reindexed_relu_bool3.append([data_idx,output_c,idx])

# %% [markdown]
# ### 패턴 중복 count

# %%
pattern_idx_df = pd.DataFrame(np.asarray(reindexed_relu_bool3),columns=["data_idx","output_channel","pattern_xs"])

# %%
groups = pattern_idx_df.groupby(["data_idx","pattern_xs"])#["output_channel"].apply(list)

# %%
pattern_repetitive_idx_df = groups["output_channel"].apply(list).reset_index(name='output_channel')

# %%
consecutive_pattern=[]
pattern_id=0

data_idx = pattern_repetitive_idx_df.loc[:,"data_idx"].values.tolist()
output_channel = pattern_repetitive_idx_df.loc[:,"output_channel"].values.tolist()
pattern_xs = pattern_repetitive_idx_df.loc[:,"pattern_xs"].values.tolist()

for d_idx, output_c,  p_xs in zip(data_idx, output_channel, pattern_xs):
    for input_c in range(trainX.shape[3]):
        pattern_dict={}
        pattern_dict["pattern_id"]= pattern_id
        pattern_dict["data_idx"] = d_idx
        pattern_dict["output_channel"] = output_c
        pattern_dict["input_channel"] = input_c
        pattern_dict["pattern_xs"]= pool3_idx_list[p_xs]
        
        short_pattern = pattern_length - len(trainX[d_idx,0,pool3_idx_list[p_xs],input_c])
            
        if short_pattern:
            pattern_dict["pattern_ys"] = np.concatenate((trainX[d_idx,0,pool3_idx_list[p_xs],input_c],np.zeros(short_pattern)))
        else:
            pattern_dict["pattern_ys"] = trainX[d_idx,0,pool3_idx_list[p_xs],input_c]
        
        consecutive_pattern.append(pattern_dict)
        pattern_id+=1

# %% [markdown]
# # unit- pattern 의 evaluation(with IOU score)

# %% [markdown]
# for data_idx in sample_data_idx:
#     data_consecutive_pattern =[x for x in consecutive_pattern if x['data_idx']==data_idx]
#     for unit_idx in range(conv3_channel):
#         data_unit_pattern = [x['pattern_ys'] for x in data_consecutive_pattern if x['output_channel']==unit_idx]
#         if len(data_unit_pattern):
#             input_pattern_label = weighted_k_means.predict(data_unit_pattern)
#             input_unit_pattern = np.zeros(n_cluster)
#             for cluster in Counter(input_pattern_label).keys():
#                 input_unit_pattern[cluster] = Counter(input_pattern_label)[cluster]
#             input_unit_pattern
#     break

# %% [markdown]
# def conv_IOU(convbool,convbool_list):
#     IOU= [(x==convbool).sum()/len(convbool) for x in convbool_list]
#     return IOU

# %% [markdown]
# relu3_IOU = np.zeros(relu_output3.shape[3]*relu_output3.shape[3]).reshape(relu_output3.shape[3],relu_output3.shape[3])

# %% [markdown]
# len(np.zeros(n_cluster*conv3_channel).reshape(conv3_channel, n_cluster))

# %% [markdown]
# # 인풋에 대해 unit별 IOU계산

# %% [markdown]
# for conv_c1 in range(relu_output3.shape[3]):
#     conv2_IOU[conv_c1][:]= conv_IOU(conv2_bool[conv_c1,:],
#                                     conv2_bool)

# %% [markdown]
# f = plt.figure(figsize=(15,15))
# ax = plt.subplot(1,1,1)
# sns.heatmap(conv2_IOU, ax = ax, cmap ="OrRd", linewidths = 0.1)
# ax.set_title("IOU scores for CONV2")
#
# #ax2 = plt.subplot(1,2,2)
# #sns.heatmap(1.0 - conv2_IOU, ax = ax2, cmap ="OrRd", linewidths = 0.1)
# #ax2.set_title("DISTANCE(1-IOU) scores for CONV2")

# %% [markdown]
# import copy

# %% [markdown]
# find_same_bool = -np.ones(128).astype(int)

# %% [markdown]
# t=0
# while (find_same_bool >-1).sum()<128:
#     find_same_bool[[i for i,x in enumerate(conv2_IOU[t]) if x==1.0 ]]=t
#     t+=1

# %% [markdown]
# np.unique(find_same_bool)

# %% [markdown]
# unit_cluster_num = len(np.unique(find_same_bool))

# %% [markdown]
# fig = plt.figure(figsize=(5,unit_cluster_num))
# for i, same_idx in enumerate(np.unique(find_same_bool)):
#     ax = plt.subplot(unit_cluster_num,1,i+1)
#     ax.imshow(conv2_bool[same_idx].reshape(1,-1).astype(int),aspect="auto",cmap="OrRd",vmin=0, vmax=1)
#     ax.set_title("UNIT-CLSUTER{}, \n# of unit in cluster:{}".format((i+1), Counter(find_same_bool)[same_idx]))
#     ax.set_yticks([])
# plt.tight_layout()

# %% [markdown]
# cg = sns.clustermap(conv1_IOU, cmap ="OrRd",
#                     linewidths = 0.1, robust=True,
#                    metric ="correlation");
# plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0)

# %% [markdown]
# Z= cg.dendrogram_col.linkage

# %% [markdown]
# from scipy.cluster.hierarchy import fcluster
# max_d = 1
# clusters = fcluster(Z, max_d, criterion='distance')
# clusters

# %% [markdown]
# k=50
# clusters =fcluster(Z, k, criterion='inconsistent')

# %% [markdown]
# clusters

# %% [markdown]
# for idx in [i for i,x in enumerate(clusters) if x==8]:
#     plt.imshow(conv2_bool[idx].T.reshape(1,-1),aspect="auto", cmap ="OrRd")
#     plt.show()

# %% [markdown]
# ## pick clustering algorithm and apply pattern weighted clustering

# %% [markdown]
# consecutive_pattern = np.load('./consecutive_pattern_randomsample(0.2).npy',allow_pickle=True)

# %% [markdown]
# # below is ongoing code

# %% [markdown]
# import numpy
# from sklearn.metrics import accuracy_score
# from keras.optimizers import Adagrad
# import matplotlib.pyplot as plt
#
# from tslearn.datasets import CachedDatasets
# from tslearn.preprocessing import TimeSeriesScalerMinMax
# from tslearn.shapelets import ShapeletModel, \
#     grabocka_params_to_shapelet_size_dict
# from tslearn.utils import ts_size
#
# numpy.random.seed(0)
#
# pattern = [pattern[i] for i,x in enumerate(pattern_weight>pattern_weight.mean()) if x]
# data_idx = [consecutive_pattern[i]['data_idx'] for i,x in enumerate(pattern_weight>pattern_weight.mean()) if x]
# pattern_weight = [pattern_weight[i] for i,x in enumerate(pattern_weight>pattern_weight.mean()) if x]
#
#
# tempY=np.asarray([trainy[x] for x in data_idx]).flatten()
# tempX =np.asarray(pattern).reshape(-1,65,1)
#
# n_ts, ts_sz = tempX.shape[:2]
# n_classes = len(set(tempY))
#
# # Set the number of shapelets per size as done in the original paper
# shapelet_sizes = grabocka_params_to_shapelet_size_dict(n_ts=n_ts,
#                                                        ts_sz=ts_sz,
#                                                        n_classes=n_classes,
#                                                        l=0.1,
#                                                        r=1)
#
# # Define the model using parameters provided by the authors (except that we use
# # fewer iterations here)
# shp_clf = ShapeletModel(n_shapelets_per_size=shapelet_sizes,
#                         optimizer=Adagrad(lr=.1),
#                         weight_regularizer=.01,
#                         max_iter=200,
#                         verbose=0)
# shp_clf.fit(tempX, tempY)
# predicted_labels = shp_clf.predict(tempX)
# print("Correct classification rate:", accuracy_score(tempY, predicted_labels))
#
# plt.figure()
# for i, sz in enumerate(shapelet_sizes.keys()):
#     plt.subplot(len(shapelet_sizes), 1, i + 1)
#     plt.title("%d shapelets of size %d" % (shapelet_sizes[sz], sz))
#     for shp in shp_clf.shapelets_:
#         if ts_size(shp) == sz:
#             plt.plot(shp.ravel())
#     plt.xlim([0, max(shapelet_sizes.keys()) - 1])
#
# plt.tight_layout()
# plt.show()
#
#
#  from sklearn.preprocessing import MinMaxScaler
#
# predicted_locations = shp_clf.locate(tempX[:10])
#
# test_ts_id = 1
# plt.figure()
# n_shapelets = sum(shapelet_sizes.values())
# plt.title("Example locations of shapelet matches "
#           "(%d shapelets extracted)".format(n_shapelets))
# plt.plot(tempX[:10][test_ts_id].ravel())
# for idx_shp, shp in enumerate(shp_clf.shapelets_):
#     t0 = predicted_locations[test_ts_id, idx_shp]
#     smin = tempX[:10][test_ts_id][t0: t0 + len(shp)].min()
#     smax = tempX[:10][test_ts_id][t0: t0 + len(shp)].max()
#
#     scaler = MinMaxScaler(feature_range=(smin, smax))
#     scaled_shp = scaler.fit_transform(shp)
#
#     gap = np.abs(tempX[:10][test_ts_id][t0: t0 + len(shp)] - scaled_shp).mean() /(smax-smin)
#     print(gap)
#     if gap > 0.18:
#         continue
#
#     plt.plot(numpy.arange(t0, t0 + len(shp)), scaled_shp, linewidth=2)
#
# plt.tight_layout()
# plt.show()

# %% [markdown]
# from sklearn import metrics
# from sklearn.metrics import pairwise_distances
#
#
# pseudoF_gmm = []
# pseudoF_kmeans = []
#
#
# cut_num=20
#
# fig = plt.figure(figsize=(20,5))
# for n_clusters in range(3,cut_num):
#     gmm = mixture.GaussianMixture(n_components=n_clusters,
#             covariance_type='full')
#     labels = gmm.fit_predict(normalized_pattern_candidate)
#     pseudoF_gmm.append(metrics.calinski_harabasz_score(normalized_pattern_candidate, labels))
#
#     kmeans = cluster.KMeans(n_clusters=n_clusters, random_state=0)
#
#     labels = kmeans.fit_predict(normalized_pattern_candidate)
#     pseudoF_kmeans.append(metrics.calinski_harabasz_score(normalized_pattern_candidate, labels))
#
# x = np.arange(3,cut_num)
# ax = plt.subplot(1,2,1)
# ax.plot(x, pseudoF_gmm[:cut_num])
# ax.set_xticks(x)
# ax.set_title("GMM pseudoF score")
# plt.grid()
#
# ax = plt.subplot(1,2,2)
# ax.plot(x, pseudoF_kmeans[:cut_num])
# ax.set_xticks(x)
# ax.set_title("Kmeans pseudoF score")
# plt.grid()
#
# plt.show()

# %% [markdown]
# best_cluster_n = 9

# %% [markdown]
# color = ["crimson","orange","olive",'seagreen',"royalblue","purple","pink","grey",
#         "crimson","orange","olive",'seagreen',"royalblue","purple","pink","grey"]
#
# random.seed(300)
#
# default_gmm = {'n_clusters':2, 'covariance_type': 'full'}
# default_kmeans = {'n_clusters':2,'verbose':False,'random_state':0}

# %% [markdown]
# g_cluster_pattern_list = []
# k_cluster_pattern_list = []
#
# gmm_option = [
#     ({'n_clusters': best_cluster_n})
# ]
#
# kmeans_option = [
#     ({'n_clusters': best_cluster_n})
# ]
#
# for g_option,k_option in zip(gmm_option,kmeans_option):
#     g_params = default_gmm.copy()
#     g_params.update(g_option)
#
#     k_params = default_kmeans.copy()
#     k_params.update(k_option)
#
#     gmm =  mixture.GaussianMixture(
#         n_components=g_params['n_clusters'],
#         covariance_type=g_params['covariance_type'])
#
#     kmeans = cluster.KMeans(
#         n_clusters=k_params['n_clusters'],
#         random_state=k_params['random_state'])
#
#     g_pred = gmm.fit_predict(normalized_pattern_candidate)
#     k_pred = kmeans.fit_predict(normalized_pattern_candidate)
#
#     fig = plt.figure(figsize=(len(np.unique(g_pred))*3,6))
#     axes = fig.subplots(2, g_params['n_clusters'])
#
#     for class_ in range(0,g_params['n_clusters']):
#         g_class_idx = [i for i,x in enumerate(g_pred) if x ==class_]
#         k_class_idx = [i for i,x in enumerate(k_pred) if x ==class_]
#
#         g_class_pattern = np.array([normalized_pattern_candidate[idx] for idx in g_class_idx])
#         k_class_pattern = np.array([normalized_pattern_candidate[idx] for idx in k_class_idx])
#
#         g_cluster_mean = g_class_pattern.mean(axis=0)
#         k_cluster_mean = k_class_pattern.mean(axis=0)
#
#         # visualization
#         axes[0,class_].plot(g_class_pattern.T, color =color[class_],alpha=0.6)
#         axes[1,class_].plot(k_class_pattern.T, color =color[class_],alpha=0.6)
#
#         axes[0,class_].plot(g_cluster_mean, color ='black',alpha=1,linewidth=5)
#         axes[1,class_].plot(k_cluster_mean, color ='black',alpha=1,linewidth=5)
#
#         # append list
#         g_cluster_pattern_list.extend([{"class":class_,"pattern_id":idx,"pattern_ys":normalized_pattern_candidate[idx],"pattern_mean":g_cluster_mean} for idx in g_class_idx])
#         k_cluster_pattern_list.extend([{"class":class_,"pattern_id":idx,"pattern_ys":normalized_pattern_candidate[idx],"pattern_mean":k_cluster_mean} for idx in k_class_idx])
#
#
#     #("KMeans: {} \nGMM: {}".format(k_params,g_params),y=1.5)
#     plt.tight_layout()
#     plt.show()

# %% [markdown]
# g_class_pattern[random.sample(range())]

# %% [markdown]
# ### remove outlier pattern for better clustering

# %% [markdown]
# 다음 알고리즘을 짜기위해 우선 건너뜀

# %% [markdown]
# import seaborn as sns

# %% [markdown]
# plt.imshow(pattern_frequency_arr.T,aspect="auto",cmap="OrRd")

# %% [markdown]
# pattern_frequency_arr.shape

# %% [markdown]
# patt

# %% [markdown]
# np.quantile(pattern_frequency_arr,0.75,0).shape

# %% [markdown]
# #conv2_bool = (pattern_frequency_arr>np.quantile(pattern_frequency_arr,0.75,0)).T

# %% [markdown]
# plt.imshow(conv2_bool,aspect="auto",cmap="OrRd")

# %% [markdown]
# ## turn off unit

# %% [markdown]
# MC_dropout_model.relu2.shape

# %% [markdown]
# plt.imshow(unit_bool[0].squeeze())

# %% [markdown]
# np.unique(find_same_bool)[0]

# %% [markdown]
# each_clustering_turnoff=[original_acc]
# for same_idx in np.unique(find_same_bool):
#     unit_bool =copy.deepcopy(true_bool)
#     for idx in [i for i,x in enumerate(find_same_bool) if x==same_idx]:
#         unit_bool[:,:,:,idx] = False
#     acc =MC_dropout_model.sess.run((MC_dropout_model.accuracy),
#                           feed_dict={MC_dropout_model.x: trainX,
#                                      MC_dropout_model.y: trainY,
#                                     MC_dropout_model.keep_prob:1.0,
#                                     MC_dropout_model.threshold_weight1 :np.ones(trainX.shape[0]*28*64).reshape(-1,1,28,64).astype(float),
#                                     MC_dropout_model.threshold_weight2 :unit_bool})
#     each_clustering_turnoff.append(acc)
#
# fig = plt.figure(figsize=(15,5))
# ax = plt.subplot(1,1,1,)
# ax.scatter(0,original_acc,c='r',s=40)
# ax.set_xticks(np.arange(0,unit_cluster_num+1))
# ax.plot(each_clustering_turnoff,c='black')
# ax.axhline(original_acc, c='r')
# ax.set_xlabel("UNIT CLUSTERING ID")
# ax.set_ylabel("ACCURACY")
# plt.grid()
# fig.suptitle("ACCURACY WHEN UNIT-CLUSTRING IS TURNED OFF ")

# %% [markdown]
# same_idx = np.unique(find_same_bool)[5]
# unit_bool =copy.deepcopy(true_bool)
# for idx in [i for i,x in enumerate(find_same_bool) if x==same_idx]:
#     unit_bool[:,:,:,idx] = False
# acc =MC_dropout_model.sess.run((MC_dropout_model.accuracy),
#                       feed_dict={MC_dropout_model.x: trainX,
#                                  MC_dropout_model.y: trainY,
#                                 MC_dropout_model.keep_prob:1.0,
#                                 MC_dropout_model.threshold_weight1 :np.ones(trainX.shape[0]*28*64).reshape(-1,1,28,64).astype(float),
#                                 MC_dropout_model.threshold_weight2 :unit_bool})

# %% [markdown]
# each_clustering_turnon=[original_acc]
# for same_idx in np.unique(find_same_bool):
#     unit_bool =copy.deepcopy(false_bool)
#     for idx in [i for i,x in enumerate(find_same_bool) if x==same_idx]:
#         unit_bool[:,:,:,idx] = True
#     acc =MC_dropout_model.sess.run((MC_dropout_model.accuracy),
#                           feed_dict={MC_dropout_model.x: trainX,
#                                      MC_dropout_model.y: trainY,
#                                     MC_dropout_model.keep_prob:1.0,
#                                     MC_dropout_model.threshold_weight1 :np.ones(trainX.shape[0]*28*64).reshape(-1,1,28,64).astype(float),
#                                     MC_dropout_model.threshold_weight2 :unit_bool})
#     each_clustering_turnon.append(acc)
#
# fig = plt.figure(figsize=(15,5))
# ax = plt.subplot(1,1,1,)
# ax.scatter(0,original_acc,c='r',s=40)
# ax.set_xticks(np.arange(0,unit_cluster_num+1))
# ax.plot(each_clustering_turnon,c='black')
# ax.axhline(original_acc, c='r')
# ax.set_xlabel("UNIT CLUSTERING ID")
# ax.set_ylabel("ACCURACY")
# plt.grid()
# fig.suptitle("ACCURACY WHEN UNIT-CLUSTRING IS TURNED ON ")

# %% [markdown]
# # clustering

# %% [markdown]
# color = ["crimson","orange","olive",'seagreen',"royalblue","purple","pink","grey",
#         "crimson","orange","olive",'seagreen',"royalblue","purple","pink","grey"]

# %% [markdown]
# n_clusters = 6

# %% [markdown]
# # clustering with fixed length data

# %% [markdown]
# 1. 패턴의 길이를 fix하고 해당 length의 패턴만을 클러스터링

# %% [markdown]
# pattern_len = 6
# specific_len_pattern_idx=[i for i,x in enumerate(consecutive_pattern) if len(x['pattern_idx']) ==pattern_len]
# specific_pattern=[x['pattern'] for i,x in enumerate(consecutive_pattern) if i in specific_len_pattern_idx]
# len(specific_len_pattern_idx)

# %% [markdown]
# ## pattern standardization
# 1. 평균0, 분산1 형태로 standardization

# %% [markdown]
# from tslearn.preprocessing import TimeSeriesScalerMeanVariance, TimeSeriesResampler
# normalized_pattern_candidate =TimeSeriesScalerMeanVariance().fit_transform(specific_pattern)
# normalized_pattern_candidate = normalized_pattern_candidate.squeeze()
# normalized_pattern_candidate.shape

# %% [markdown]
# ## spectral clustering, gmm clustering,k-means,SOM

# %% [markdown]
# from sklearn import mixture,cluster
# from tslearn.clustering import TimeSeriesKMeans

# %% [markdown]
# #n_cluster : interger
# #eigen_solver{None, ‘arpack’, ‘lobpcg’, or ‘amg’}
# #affinity: ‘nearest_neighbors’‘rbf’
# default_spectral = {'n_clusters':2,
#                     'eigen_solver': 'arpack',
#                     'affinity': "rbf"}
#
# #covariance_type{‘full’ (default), ‘tied’, ‘diag’, ‘spherical’}
# default_gmm = {'n_clusters':2, 'covariance_type': 'full'}
# default_kmeans = {'n_clusters':2,'verbose':False,'random_state':0}
# default_hac = {'method':'single','metric':'euclidean','cut_off_level':5,'criterion':'maxclust'}
#
# spectral_option = [
#     ({'n_clusters': 6})
# ]
#
# gmm_option = [
#     ({'n_clusters': 6})
#
# ]
#
# kmeans_option = [
#     ({'n_clusters': 6})
#
# ]
#
# hac_option =[
#     ({'cut_off_level': 6})
#
# ]

# %% [markdown]
# import math
# import scipy.cluster.hierarchy as hac
# import matplotlib.gridspec as gridspec

# %% [markdown]
# random.seed(300)
# for g_option,k_option in zip(gmm_option,kmeans_option):
#
#     g_params = default_gmm.copy()
#     g_params.update(g_option)
#
#     k_params = default_kmeans.copy()
#     k_params.update(k_option)
#
#
#     gmm =  mixture.GaussianMixture(
#         n_components=g_params['n_clusters'],
#         covariance_type=g_params['covariance_type'])
#
#     kmeans = cluster.KMeans(
#         n_clusters=k_params['n_clusters'],
#         random_state=k_params['random_state'])
#
#     g_pred = gmm.fit_predict(normalized_pattern_candidate)
#     k_pred = kmeans.fit_predict(normalized_pattern_candidate)
#
#     g_cluster_mean_pattern =[]
#     k_cluster_mean_pattern =[]
#
#     fig = plt.figure(figsize=(len(np.unique(g_pred))*3,7))
#     axes = fig.subplots(2, g_params['n_clusters'])
#     for class_ in range(0,g_params['n_clusters']):
#         g_class_idx = [i for i,x in enumerate(g_pred) if x ==class_]
#         k_class_idx = [i for i,x in enumerate(k_pred) if x ==class_]
#
#         try:
#             axes[0,class_].plot(normalized_pattern_candidate[random.sample(g_class_idx,30)].T, color =color[class_],alpha=0.6)
#             axes[1,class_].plot(normalized_pattern_candidate[random.sample(k_class_idx,30)].T, color =color[class_],alpha=0.6)
#
#         except:
#             axes[0,class_].plot(normalized_pattern_candidate[g_class_idx].T, color =color[class_],alpha=0.6)
#             axes[1,class_].plot(normalized_pattern_candidate[k_class_idx].T, color =color[class_],alpha=0.6)
#
#         g_cluster_mean = normalized_pattern_candidate[g_class_idx].mean(axis=0)
#         g_cluster_mean_pattern.append(g_cluster_mean)
#         k_cluster_mean = normalized_pattern_candidate[k_class_idx].mean(axis=0)
#         k_cluster_mean_pattern.append(k_cluster_mean)
#         axes[0,class_].plot(g_cluster_mean, color ='black',alpha=1,linewidth=5)
#         axes[1,class_].plot(k_cluster_mean, color ='black',alpha=1,linewidth=5)
#
#     #fig.suptitle("Spectral Clustering: {} \nGMM: {}".format(s_params,g_params),y=0.98)
#     plt.tight_layout()

# %% [markdown]
# import more_itertools as mit
# from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# prediction = MC_dropout_model.predict(data=trainX,keep_prob=1.0,is_dropout=False,threshold_weight = np.ones(trainX.shape[0]*128*128).reshape(-1,1,128,128))

# %% [markdown]
# #sample_data_idx = [i for i,x in enumerate(prediction) if np.argmax(x)==1]
# sample_data_idx = [i for i,x in enumerate(prediction) if np.argmax(x)==0]

# %% [markdown]
# plot_idx = 0
#
# for d_idx in sample_data_idx:
# ######## 특정 샘플의 패턴 리스트 생성
#     # sample_data_idx의 전체 패턴
#     specific_data_pattern_idx=[i for i,x in enumerate(consecutive_pattern) if x['data_idx'] ==d_idx]
#     specific_pattern_idx= list(set(specific_data_pattern_idx) & set(specific_len_pattern_idx))
#     specific_pattern_info = [consecutive_pattern[x] for x in specific_pattern_idx]
#
#     #해당 데이터에 미리 정한 길이만큼의 패턴이 없을 경우 pass
#     if len(specific_pattern_info):
#         pass
#
#     # 총 10개의 plot을 그릴때까지 진행
#     if plot_idx ==15:
#         break
#
#     for p_idx,p_info in zip(specific_pattern_idx, specific_pattern_info):
#         plot_idx+=1
#         # 데이터 자체 그리기
#         fig, ax= plt.subplots(figsize=(15,3))
#         ax.set_xlim([0,int(trainX.shape[2])-1])
#         data = trainX[d_idx,0,:,input_pattern_channel]
#         ax.plot(data,color='black')
#
#         highlight_bool = np.zeros(width).astype(bool)
#         for p_channel in p_info['pattern_channel']:
#             hightlight_bool = (highlight_bool | last_conv_bool[d_idx,:,p_channel])
#
#
#         ax.set_facecolor("grey") # 패턴이 있는 부분만 흰색 spotlight으로 하기 위해 기본 배경을 회색으로 설정
#
#         for spotlight_se in [(list(group)) for group in mit.consecutive_groups([i for i,x in enumerate(hightlight_bool) if x==True])]:
#             ax.axvspan(spotlight_se[0], spotlight_se[-1], color='white', alpha=1)
#
#         color_idx = g_pred[specific_len_pattern_idx.index(p_idx)]
#         pattern_idx = p_info['pattern_idx']
#         ax.plot(pattern_idx, data[pattern_idx], color = color[color_idx])
#
#         # 패턴의 평균값 굵고 투명하게 그리기
#         x = g_cluster_mean_pattern[color_idx].reshape(-1,1) #returns a numpy array
#         min_max_scaler = MinMaxScaler(feature_range=(data[pattern_idx].min(), data[pattern_idx].max()))
#         pattern_scaled = min_max_scaler.fit_transform(x)
#         ax.plot(pattern_idx, pattern_scaled, color = color[color_idx], alpha=0.4,linewidth=10)
#         fig.suptitle("data{} : label{}, prediction{} \n in last conv output_channel{}".format(d_idx, np.argmax(trainY[d_idx]),np.argmax(prediction[d_idx]),p_info['pattern_channel']),y=1.0)
#     plt.show()

# %% [markdown]
# ## clustering with different length scale

# %% [markdown]
# #### Global Alignmnet Kernel K Means

# %% [markdown]
# pattern_len = 6
# specific_len_pattern_idx=[i for i,x in enumerate(consecutive_pattern)]
# specific_pattern=[x['pattern'] for i,x in enumerate(consecutive_pattern) if i in specific_len_pattern_idx]
# len(specific_len_pattern_idx)

# %% [markdown]
# from tslearn.utils import to_time_series_dataset
# from tslearn.clustering import GlobalAlignmentKernelKMeans

# %% [markdown]
# #길이를 맞추기위해 nan으로 패딩
# X =to_time_series_dataset(specific_pattern)

# %% [markdown]
# gak_km = GlobalAlignmentKernelKMeans(n_clusters=n_clusters)
# gak_km_predict = gak_km.fit_predict(X)
#
# class_breakdown(gak_km_predict)

# %% [markdown]
# for n in range(n_clusters):
#     idx = [i for i,x in enumerate(gak_km_predict) if x==n]
#     vars()["pattern_"+str(n)] = [pattern[i] for i in idx ]

# %% [markdown]
# plt.figure(figsize=(20,5))
# for n in range(n_clusters):
#     ax= plt.subplot(1,n_clusters,n+1)
#     for p in eval("pattern_"+str(n)):
#         ax.plot(range(len(p)),p,color = color[n])
# plt.tight_layout()

# %% [markdown]
# plt.figure(figsize=(20,5))
# for n in range(n_clusters):
#     ax= plt.subplot(1,n_clusters,n+1)
#     mindexes = [np.argmax(x) for x in eval("pattern_"+str(n))]
#     vars()["norm_pattern_"+str(n)] = [(x-min(x)) for x in eval("pattern_"+str(n))]
#     for i,p in enumerate(eval("norm_pattern_"+str(n))):
#         shifts = max(mindexes) - mindexes[i]
#         ax.plot(range(shifts,shifts+len(p)), p,color=color[n],alpha=0.2)
#
# plt.show()

# %% [markdown]
# ### find representative shape for each clustering

# %% [markdown]
# #### 1. Using U shapelet
# ref: Clustering Time Series using Unsupervised-Shapelets

# %% [markdown]
# len(pattern)

# %% [markdown]
# import copy
# sLen = range(5,9)
# D=copy.deepcopy(pattern)

# %% [markdown]
# S_hat=[]
# ts=D[50]
# for _ in range(10):
#     cnt=0 #count of candidate u-shapelets from ts
#     s_hat ={} #set of subsequences, initially empty
#     gap = []
#     dt =[]
#
#     for sl in sLen:#each u-shapelet length
#         for i in np.arange(0, len(ts)-sl +1):#each subsequence from ts
#             s_hat[cnt] = ts[i:i+sl] #a subsequence of length sl
#             tup = compute_gap(s_hat[cnt],D,6)
#             gap.append(tup[0])
#             dt.append(tup[1])
#             cnt+=1
#     if cnt>0:
#         index1 = np.argmax(gap)
#         S_hat.append(s_hat[index1]) #find maximum gap score
#         dis = compute_distance(s_hat[index1],D)#add the u-shapelet with max gap score
#         try:
#             dA= [dis[i] for i,x in enumerate(dis<dt[index1]) if x==True] #points to the left of dt
#         except:
#             dA = [dis[i] for i,x in enumerate(dis) if x<dt[0]]
#
#         if len(dA) ==1:
#             print("dA length:1")
#             break
#         else:
#             index2 = np.argmax(dis)
#             ts = D[index2]
#             msdA= np.mean(dA) +np.std(dA)
#             D_hat = [i for i,x in enumerate(dis<msdA) if x ==True]
#             idx = [x for x in np.arange(0,len(D)) if x not in D_hat]
#             new_D=[]
#             for d_idx in idx:
#                 new_D.append(D[d_idx])
#             D=new_D

# %% [markdown]
# def znorm(data):
#     return (data-min(data))/(max(data)-min(data))

# %% [markdown]
# def euclidean_d(data1,data2):
#     return np.linalg.norm(data1-data2)

# %% [markdown]
# def compute_gap(sub, data,cluster_num):
#     dis= compute_distance(sub,data)
#     dis = np.sort(dis)
#     maxGap = 0
#     dt = 0
#     for l in range(1, len(dis)-1):
#         d = (dis[l]+dis[l+1])/2
#
#         dA = dis[dis<d]
#         dB = dis[dis>d]
#         try:
#             r = len(dA)/len(dB)
#             if ((1/cluster_num < r) and (1-(1/cluster_num))):
#                 mA = dA.mean()
#                 mB = dB.mean()
#                 sA = dA.std()
#                 sB = dB.std()
#                 gap = mB-sB-(mA+sA)
#                 if gap > maxGap :
#                     #print("gap {}".format(gap))
#                     maxGap =gap
#                     dt =d
#         except:
#             pass
#     return maxGap, dt

# %% [markdown]
# def compute_distance(sub, data):
#     dis=[10e3]*len(data)
#     sub = znorm(sub)
#     for i in range(0,len(data)):
#         ts = data[i]
#
#         for j in range(0, len(ts)-len(sub)):
#             z = znorm(ts[j:j+len(sub)])
#             d = euclidean_d(z,sub)
#             dis[i]= min(d,dis[i])/np.sqrt(len(sub))
#         #print(dis[i])
#     return dis

# %% [markdown]
# #### 2. Use dtw measure

# %% [markdown]
# from dtwalign import dtw

# %% [markdown]
# x = norm_pattern_5[60]
# y = norm_pattern_5[0]
# res = dtw(x,y)
#
# # dtw distance
# print("dtw distance: {}".format(res.distance))
# print("dtw normalized distance: {}".format(res.normalized_distance))
#
# """
# if you want to calculate only dtw distance (i.e. no need to gain alignment path),
# give 'distance_only' argument as True (it makes faster).
# """
# #res = dtw(x,y,distance_only=True)

# %% [markdown]
# ax = plt.subplot(2,1,1)
# ax.plot(x,color="blue")
# ax.plot(y,color="red")
# ax.set_ylim(0,1)
# # warp both x and y by alignment path
# x_path = res.path[:,0]
# y_path = res.path[:,1]
#
# ax = plt.subplot(2,1,2)
# ax.plot(x[x_path],label="aligned query",color="blue")
# ax.plot(y[y_path],label="aligned reference",color="red")
# ax.legend()
# ax.set_ylim(0,1)

# %% [markdown]
# # visualize alignment path with cumsum cost matrix
# res.plot_path()

# %% [markdown]
# prediction = MC_dropout_model.predict(data=trainX,keep_prob=1.0,is_dropout=False)

# %% [markdown]
# #sample_data_idx = [i for i,x in enumerate(prediction) if np.argmax(x)==1]
# sample_data_idx = [i for i,x in enumerate(prediction) if np.argmax(x)==0]

# %% [markdown]
# plot_idx = 0
#
# for d_idx in sample_data_idx:
# ######## 특정 샘플의 패턴 리스트 생성
#     # sample_data_idx의 전체 패턴
#     specific_data_pattern_idx=[i for i,x in enumerate(consecutive_pattern) if x['data_idx'] ==d_idx]
#     specific_pattern_info = [consecutive_pattern[x] for x in specific_data_pattern_idx]
#
#     #해당 데이터에 미리 정한 길이만큼의 패턴이 없을 경우 pass
#     if len(specific_pattern_info):
#         pass
#
#     # 총 10개의 plot을 그릴때까지 진행
#     if plot_idx ==5:
#         break
#
#     for p_channel in np.unique([(x['pattern_channel']) for x in specific_pattern_info if (x['data_idx']==d_idx)]):
#         plot_idx+=1
#         fig, ax= plt.subplots(figsize=(15,3))
#         ax.set_xlim([0,int(trainX.shape[2])-1])
#         spotlight = last_conv_bool[d_idx,:,p_channel]
#
#         # 데이터 자체 그리기
#         data = trainX[d_idx,0,:,input_channel]
#         ax.plot(data,color='black')
#         ax.set_facecolor("grey") # 패턴이 있는 부분만 흰색 spotlight으로 하기 위해 기본 배경을 회색으로 설정
#
#         for spotlight_se in [(list(group)) for group in mit.consecutive_groups([i for i,x in enumerate(spotlight) if x==True])]:
#             ax.axvspan(spotlight_se[0], spotlight_se[-1], color='white', alpha=1)
#
#         for idx,pattern_x, pattern in [(i,x['pattern_idx'],x['pattern']) for i,x in enumerate(specific_pattern_info) if (x['data_idx']==d_idx  and x['pattern_channel']== p_channel)]:
#             # 데이터의 해당 패턴 그리기
#             pattern_idx = specific_data_pattern_idx[idx]
#             color_idx = gak_km_predict[specific_data_pattern_idx.index(pattern_idx)]
#             pattern_x = consecutive_pattern[pattern_idx]['pattern_idx']
#             #pattern = consecutive_pattern[pattern_idx]['pattern']
#             ax.plot(pattern_x, data[pattern_x], color = color[color_idx])
#         fig.suptitle("prediction{}, data{}, output_channel{}".format(np.argmax(prediction[d_idx]),d_idx,consecutive_pattern[pattern_idx]['pattern_channel']))
#         break
#
#
#     plt.show()

# %% [markdown]
# # Below part is still unclear

# %% [markdown]
# f = open('file.txt', 'a+t')
# for i,x in enumerate(X):
#     for x_ in x:
#         f.write(str(x_[0])+",")
#     f.write(":"+str(gak_km_predict[i])+"\n")
#
# f.close()

# %% [markdown]
# X_df = pd.DataFrame(columns=["dim_0"],index=range(len(X)))
# for i,x in enumerate(X):
#     X_df.iloc[i,0] = x

# %% [markdown]
# Y_df =gak_km_predict.astype('<U1')

# %% [markdown]
# from sktime.transformers.shapelets import ContractedShapeletTransform
# # How long (in minutes) to extract shapelets for.
# # This is a simple lower-bound initially; once time is up, no further shapelets will be assessed
# time_limit_in_mins = 1
#
# # The initial number of shapelet candidates to assess per training series. If all series are visited
# # and time remains on the contract then another pass of the data will occur
# initial_num_shapelets_per_case = 5
#
# # Whether or not to print on-going information about shapelet extraction. Useful for demo/debugging
# verbose = 2
#
# st = ContractedShapeletTransform(
#     time_limit_in_mins=time_limit_in_mins,
#     num_candidates_to_sample_per_case=initial_num_shapelets_per_case,
#     verbose=verbose)
# st.fit(X_df, Y_df)

# %% [markdown]
# # for each extracted shapelet (in descending order of quality/information gain)
# for s in st.shapelets:
#
#     # summary info about the shapelet
#     print(s)
#
#     # plot the series that the shapelet was extracted from
#     plt.plot(
#         X[s.series_id],
#         'gray'
#     )
#
#     # overlay the shapelet onto the full series
#     plt.plot(
#         list(range(s.start_pos,(s.start_pos+s.length))),
#         X[s.series_id,s.start_pos:s.start_pos+s.length],
#         'r',
#         linewidth=3.0
#     )
#     plt.show()

# %% [markdown]
# ## hierarchical clustering

# %% [markdown]
# import math
# import scipy.cluster.hierarchy as hac
# import matplotlib.gridspec as gridspec
#
# D = hac.linkage(normalized_pattern_candidate[:20], method='single',metric='euclidean')
# cut_off_level = 5
# #Dendrogram
# plt.figure(figsize=(15, 5))
# plt.title('Dendrogram of time series clustering',fontsize=25, fontweight='bold')
# plt.xlabel('sample index', fontsize=25, fontweight='bold')
# plt.ylabel('distance', fontsize=25, fontweight='bold')
# hac.dendrogram(D, leaf_rotation=90., leaf_font_size=15., ) # font size for the x axis labels
# plt.show()

# %% [markdown]
# 특정 파라미터에 해당하는 클러스터 시각화

# %% [markdown]
# import matplotlib.patheffects as pe

# %% [markdown]
# random.seed(300)
# sample_data_idx = random.sample(range(0,len(normalized_pattern_candidate)),len(normalized_pattern_candidate))
# color = ["crimson","orange","olive",'seagreen',"royalblue","purple","pink","grey",
#         "crimson","orange","olive",'seagreen',"royalblue","purple","pink","grey"]

# %% [markdown]
# for s_option,g_option,k_option in zip(spectral_option[::-1],gmm_option[::-1],kmeans_option[::-1]):
#     s_params = default_spectral.copy()
#     s_params.update(s_option)
#
#     g_params = default_gmm.copy()
#     g_params.update(g_option)
#
#     k_params = default_kmeans.copy()
#     k_params.update(k_option)
#
#     spectral = cluster.SpectralClustering(
#         n_clusters=s_params['n_clusters'],
#         eigen_solver=s_params['eigen_solver'],
#         affinity=s_params['affinity'])
#
#     gmm =  mixture.GaussianMixture(
#         n_components=g_params['n_clusters'],
#         covariance_type=g_params['covariance_type'])
#
#     kmeans = cluster.KMeans(
#         n_clusters=k_params['n_clusters'],
#         random_state=k_params['random_state'])
#
#     spectral.fit(normalized_pattern_candidate)
#     gmm.fit(normalized_pattern_candidate)
#     kmeans.fit(normalized_pattern_candidate)
#
#     s_pred = spectral.labels_[sample_data_idx]
#     g_pred = gmm.predict(normalized_pattern_candidate[sample_data_idx])
#     k_pred = kmeans.fit_predict(normalized_pattern_candidate[sample_data_idx])
#
#     num_class = len(list(set(np.unique(s_pred)).union(set(np.unique(g_pred)))))
#     fig = plt.figure(figsize=(18,5))
#     axes = fig.subplots(3,num_class)
#
#     for class_ in range(0,num_class):
#         class_idx = [i for i,x in enumerate(s_pred) if x ==class_]
#         try:
#             axes[0][class_+1].plot(normalized_pattern_candidate[[sample_data_idx[x] for x in class_idx]].T, color =color[class_],alpha=0.6)
#             axes[0][0].plot(normalized_pattern_candidate[[sample_data_idx[x] for x in class_idx]].mean(axis=0), color = 'black',alpha=1,linewidth=3,
#                    path_effects=[pe.Stroke(linewidth=10, foreground=color[class_]), pe.Normal()])
#         except:
#             pass
#
#         class_idx = [i for i,x in enumerate(g_pred) if x ==class_]
#         try:
#             axes[1][class_+1].plot(normalized_pattern_candidate[[sample_data_idx[x] for x in class_idx]].T, color =color[class_],alpha=0.6)
#             axes[1][0].plot(normalized_pattern_candidate[[sample_data_idx[x] for x in class_idx]].mean(axis=0), color ='black',alpha=1,linewidth=3,
#                     path_effects=[pe.Stroke(linewidth=10, foreground=color[class_]), pe.Normal()])
#         except:
#             pass
#         class_idx = [i for i,x in enumerate(k_pred) if x ==class_]
#         try:
#             axes[2][class_+1].plot(normalized_pattern_candidate[[sample_data_idx[x] for x in class_idx]].T, color =color[class_],alpha=0.6)
#             axes[2][0].plot(normalized_pattern_candidate[[sample_data_idx[x] for x in class_idx]].mean(axis=0), color ='black',alpha=1,linewidth=3,
#                     path_effects=[pe.Stroke(linewidth=10, foreground=color[class_]), pe.Normal()])
#         except:
#             pass
#     #fig.suptitle("Spectral Clustering: {} \nGMM: {}".format(s_params,g_params),y=0.98)
#     plt.tight_layout()
#     break

# %% [markdown]
# ### 2. clustering time series using unsupervised shapelets

# %% [markdown]
# D =pattern.copy(deep=True)
# sLen = range(6,32)
#
# S_hat={}
# ts =D[500]

# %% [markdown]
# len(pattern)

# %% [markdown]
# s_option =spectral_option[-1]
# g_option=gmm_option[-1]
# s_params = default_spectral.copy()
# s_params.update(s_option)
#
# g_params = default_gmm.copy()
# g_params.update(g_option)
#
# spectral = cluster.SpectralClustering(
#     n_clusters=s_params['n_clusters'],
#     eigen_solver=s_params['eigen_solver'],
#     affinity=s_params['affinity'])
#
# gmm =  mixture.GaussianMixture(
#     n_components=g_params['n_clusters'],
#     covariance_type=g_params['covariance_type'])
#
# s_pred = spectral.fit_predict(normalized_pattern_candidate)
# g_pred = gmm.fit_predict(normalized_pattern_candidate)
#
# s_representative_pattern =[]
# g_representative_pattern =[]
# for class_ in np.unique(s_pred):
#
#     s_class_idx = [i for i,x in enumerate(s_pred) if x ==class_]
#     s_representative_pattern.append(normalized_pattern_candidate[s_class_idx].mean(axis=0))
#
#     g_class_idx = [i for i,x in enumerate(g_pred) if x ==class_]
#     g_representative_pattern.append(normalized_pattern_candidate[g_class_idx].mean(axis=0))

# %% [markdown]
# from mpl_toolkits.mplot3d import axes3d
#
# fig = plt.figure(figsize=(20,8))
# ax = fig.add_subplot(1, 2, 1,projection='3d')
#
# x = ((g_representative_pattern[0]*len(normalized_pattern_candidate)-normalized_pattern_candidate)**2).sum(axis=1)
# y = ((g_representative_pattern[1]*len(normalized_pattern_candidate)-normalized_pattern_candidate)**2).sum(axis=1)
# z = ((g_representative_pattern[2]*len(normalized_pattern_candidate)-normalized_pattern_candidate)**2).sum(axis=1)
#
# ax.scatter(x,y,z, c = g_pred)
#
# ax.set_xlabel('class1')
# ax.set_ylabel('class2')
# ax.set_zlabel('class3')
# ax.set_xticks([])
# ax.set_yticks([])
# ax.set_zticks([])
# #ax.axis('off')
#
# ax2 = fig.add_subplot(1, 2, 2,projection='3d')
#
# x = ((s_representative_pattern[0]*len(normalized_pattern_candidate)-normalized_pattern_candidate)**2).sum(axis=1)
# y = ((s_representative_pattern[1]*len(normalized_pattern_candidate)-normalized_pattern_candidate)**2).sum(axis=1)
# z = ((s_representative_pattern[2]*len(normalized_pattern_candidate)-normalized_pattern_candidate)**2).sum(axis=1)
#
# ax2.scatter(x,y,z, c = s_pred)
#
# ax2.set_xlabel('class1')
# ax2.set_ylabel('class2')
# ax2.set_zlabel('class3')
# ax2.set_xticks([])
# ax2.set_yticks([])
# ax2.set_zticks([])

# %% [markdown]
# color = ["crimson","orange","olive",'seagreen',"royalblue","purple","pink","grey",
#         "crimson","orange","olive",'seagreen',"royalblue","purple","pink","grey"]
# random.seed(300)
# for s_option,g_option in zip(spectral_option,gmm_option):
#     s_params = default_spectral.copy()
#     s_params.update(s_option)
#
#     g_params = default_gmm.copy()
#     g_params.update(g_option)
#
#     spectral = cluster.SpectralClustering(
#         n_clusters=s_params['n_clusters'],
#         eigen_solver=s_params['eigen_solver'],
#         affinity=s_params['affinity'])
#
#     gmm =  mixture.GaussianMixture(
#         n_components=g_params['n_clusters'],
#         covariance_type=g_params['covariance_type'])
#
#     s_pred = spectral.fit(normalized_pattern_candidate)
#     g_pred = gmm.fit(normalized_pattern_candidate)
#
#     sample_data_idx = random.sample(range(0,len(normalized_pattern_candidate)),100)
#
#     s_pred = spectral.labels_[sample_data_idx]
#     g_pred = gmm.predict(normalized_pattern_candidate[sample_data_idx])
#
#     fig = plt.figure(figsize=(15,3))
#     for class_ in np.unique(s_pred):
#         ax = plt.subplot(1,2,1)
#         class_idx = [sample_data_idx[i] for i,x in enumerate(s_pred) if x ==class_]
#         ax.plot(normalized_pattern_candidate[class_idx].T, color =color[class_],alpha=0.2)
#         ax.plot(normalized_pattern_candidate[class_idx].mean(axis=0), color =color[class_],alpha=1,linewidth=5)
#
#         ax2 = plt.subplot(1,2,2)
#         class_idx = [sample_data_idx[i] for i,x in enumerate(g_pred) if x ==class_]
#         try:
#             #ax2.plot(normalized_pattern_candidate[class_idx].T, color =color[class_],alpha=0.2)
#             ax2.plot(normalized_pattern_candidate[class_idx].mean(axis=0), color =color[class_],alpha=1,linewidth=5)
#         except:
#             continue
#
#     fig.suptitle("Spectral Clustering: {} \nGMM: {}".format(s_params,g_params))
#     plt.tight_layout()

# %% [markdown]
# ### plotly visualization을 위해 샘플 데이터 및 패턴 저장

# %% [markdown]
# sample_data_idx=87
# sample_output_channel = 79
# sample_data = pd.DataFrame(trainX[sample_data_idx].reshape(-1,9))

# %% [markdown]
# sample_pattern_bool =pd.DataFrame(last_conv_bool[sample_data_idx][:,sample_output_channel])
# pattern_idx = [p for p, x in enumerate(last_conv_bool[sample_data_idx][:,sample_output_channel]) if x]

# %% [markdown]
# last_conv_bool[sample_data_idx][:,sample_output_channel].sum()

# %% [markdown]
# groups = []
# for _, g in groupby(pattern_idx, key=lambda n, c=itertools.count(): n-next(c)):
#     groups.append(list(g))    # Store group iterator as a list

# %% [markdown]
# consecutive_pattern=[]
# for g in groups:
#     if len(g)>consecutive_num:
#         consecutive_pattern.extend(g)
#
# consecutive_pattern_bool=[]
# for x in range(0,128):
#     if x in np.asarray(consecutive_pattern).flatten():
#         consecutive_pattern_bool.append(True)
#     else:
#         consecutive_pattern_bool.append(False)

# %% [markdown]
# sample_consecutive_pattern_bool= pd.DataFrame(consecutive_pattern_bool)

# %% [markdown]
# sample_data.to_csv('./sample_data+pattern/'+str(sample_data_idx)+'_data.csv')
# sample_pattern_bool.to_csv('./sample_data+pattern/'+str(sample_data_idx)+'_pattern.csv')
# sample_consecutive_pattern_bool.to_csv('./sample_data+pattern/'+str(sample_data_idx)+'_consecutive_pattern.csv')

# %% [markdown]
# ## 2d visualization

# %% [markdown]
# import plotly
# from plotly.subplots import make_subplots
# import plotly.graph_objects as go
#
# DEFAULT_PLOTLY_COLORS=['rgba(31, 119, 180, {})', 'rgba(255, 127, 14, {})',
#                        'rgba(44, 160, 44, {})', 'rgba(214, 39, 40, {})',
#                        'rgba(148, 103, 189, {})', 'rgba(140, 86, 75, {})',
#                        'rgba(227, 119, 194, {})', 'rgba(127, 127, 127, {})',
#                        'rgba(188, 189, 34, {})', 'rgba(23, 190, 207, {})']
#
# normalized_data = (sample_data.values - sample_data.values.min(axis=0))/(sample_data.values.max(axis=0) - sample_data.values.min(axis=0))
# for cidx in range(0,sample_data.shape[1]):
#     normalized_data[:,cidx] =normalized_data[:,cidx] + cidx
#
#
# fig = make_subplots(
#     rows=1, cols=1, shared_xaxes=True, vertical_spacing=0.02
# )
#
# for cidx in range(sample_data.shape[-1]):
#     fig.add_trace(go.Scatter(x=np.arange(sample_data.shape[0]),
#                              y=normalized_data[:,cidx],
#                             line_color="black",
#                              line_width=1,
#                              showlegend=False,
#                              ),
#                   row=1, col=1)
#
#     fig.add_trace(go.Scatter(x=np.arange(sample_data.shape[0])[consecutive_pattern_bool],
#                             y=normalized_data[consecutive_pattern_bool,cidx],
# #                               fill='toself',
#                             line_color='rgba(200, 0, 200, 0.6)',
#                             line_width=5,
#                             showlegend=False,
#                             ),
#                    row=1, col=1)
#
# fig.update_xaxes(showline=True, linewidth=2, linecolor='black',ticks="inside")
# fig.update_yaxes(showline=True, linewidth=2, linecolor='black',
#                  ticks="inside",nticks=sample_data.shape[1], tickwidth=2, tickcolor='black', ticklen=10,title_text='Input Channel',
#                 showgrid=True, gridwidth=1, gridcolor='grey',
#                 ticktext=["Channel1", "Channel2", "Channel3", "Channel4","Channel5", "Channel6", "Channel7", "Channel8", "Channel9"],
#                 tickvals=["1", "2", "3", "4", "5", "6","7", "8", "9"],
#                 range=[0,9])
#
#
# fig.update_layout(height=600, width=800,plot_bgcolor='rgb(256,256,256)',
#                   title_text="Input")
#
# fig.show()

# %% [markdown]
# ## 3d visualization

# %% [markdown]
# from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook
# %matplotlib inline
# %matplotlib qt

# %% [markdown]
# random.seed = 10005
#
# class_color= ["cyan","orange","lime","pink","cyan","orange","lime","pink","cyan"]
# consecutive_class_color= ["dodgerblue","coral","seagreen","indianred","dodgerblue","coral","seagreen","indianred","dodgerblue"]
# survived_channel = [i for i, x in enumerate(last_conv_bool.sum(axis=1).sum(axis=0)) if x>0]
# sample_channel = random.sample(survived_channel,1)
#
# consecutive_num =trainX.shape[2]//20
#
# for class_i in class_list:
#
#     sample_data_idx =random.sample([i for i, e in enumerate(np.argmax(trainY,axis=1)) if e == (class_i-1)],1)
#     fig = plt.figure()
#     ax = fig.add_subplot(111,projection='3d')
#     fig.suptitle("Last Conv ({}) Consecutive ({}) ,Output(class{}) ".format(sample_channel,consecutive_num,class_i-1))
#
#     for c in range(0,input_channel):
#         data = trainX[sample_data_idx,:,:,c].reshape(-1,1)
#         data = (data-data.min())/(data.max()-data.min())
#         pattern_idx = [p for p, x in enumerate(last_conv_bool[sample_data_idx[0],:,c]) if x]
#         #ax = fig.gca(projection='3d')
#
#         ax.plot([c]*len(data),range(0,len(data)), data.flatten())
#         # 패턴의 연속성을 찾는 구간
#         groups = []
#         for _, g in groupby(pattern_idx, key=lambda n, c=itertools.count(): n-next(c)):
#             groups.append(list(g))    # Store group iterator as a list
#         for g in groups:
#             if len(g)>consecutive_num:
#                 ax.scatter([c]*len(g) ,g,data[g],color = consecutive_class_color[c], s =12,alpha=0.7)
#                 #ax.add_collection3d(plt.fill_between(np.arange(g[0],g[-1]),data[g[0]:g[-1]],0), zs=1, zdir='y')
#                 #ax[j].text(g[0],0,len(g))
#             #else:
#                 #ax.scatter(g,[c]*len(g), data[g],color = class_color[c],s=12)
#
#         ax.set_xticks=[]
#         ax.set_yticks=[]
#         #ax.get_proj = lambda: np.dot(Axes3D.get_proj(ax), np.diag([1, 0.8, 0.2, 1]))
#     break
